# %% [markdown]
# # Vizualization Lab

# %% [markdown]
# ## Config

# %%
import sys

sys.path.append('c:/Users/Jordi Cremades/Documents/Repos/central-node')

from src import query_engines, dataframe_visualizer

q = query_engines.QueryEngines()

# %% [markdown]
# ## Query data

# %%
N_DAYS = '8'

params = [{'name':'n_days', 'value':N_DAYS}]

q.prepare_query(
    query_file='dataset1.sql'
    ,params=params
    ,to_load_file=None
    ,load_from_to_load_file=None
)

df = q.query_run_starburst()
df.head()
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#   p_creation_date  n_orders  n_customers
# 0      2024-09-15    927227       811259
# 1      2024-09-14    902135       784159
# 2      2024-09-13    885645       778604
# 3      2024-09-12    761335       669686
# 4      2024-09-11    771867       677921

# %% [markdown]
# ## one_variable_lineplot

# %%
v = dataframe_visualizer.DataFrameVisualizer(df)

X_COLUMN = 'p_creation_date'
y_COLUMN = 'n_orders'
COLOR = 'blue'

v.one_variable_lineplot(X_COLUMN, y_COLUMN, color=COLOR)
# Out:
# ['blue']

# %% [markdown]
# ## multiple_variable_lineplot

# %%
v = dataframe_visualizer.DataFrameVisualizer(df)

X_COLUMN = 'p_creation_date'
Y_COLUMNS = ['n_orders','n_customers']
COLORS = ['blue', 'orange']

v.multiple_variable_lineplot(X_COLUMN, Y_COLUMNS, colors=COLORS)
