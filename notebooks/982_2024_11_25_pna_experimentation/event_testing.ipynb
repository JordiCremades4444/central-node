# %% [markdown]
# # Event Testing

# %%
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns
import sys

# Move two levels up (to the project root) and append the `src` folder
src_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))

# Append src to sys.path
sys.path.append(src_path)

from src import query_engines, dataframe_visualizer

q = query_engines.QueryEngines()

# %% [markdown]
# # Event Testing

# %%
QUERY_NAME = 'instruction_impression.sql' # Without .sql added
START_DATE = "'2024-11-22'"
END_DATE = "'2024-11-25'"

params = [
    {'name':'start_date', 'value': str(START_DATE)},
    {'name':'end_date', 'value': str(END_DATE)}
]

q.prepare_query(
    QUERY_NAME
    ,params=params
    ,to_load_file=QUERY_NAME
    ,load_from_to_load_file=None
)

df  = q.query_run_starburst()
df
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/0c12ce884ba789ccc40f1c7621ae17b9572665ceca19da8198ae1e40d3bb064a
#   creation_date              event_name custom_attributes__instruction_type  \
# 0    2024-11-22  Instruction Impression               ProductInstructionPNA
# 1    2024-11-22  Instruction Impression               ProductInstructionPNA
# 2    2024-11-23  Instruction Impression               ProductInstructionPNA
# 3    2024-11-23  Instruction Impression               ProductInstructionPNA
# 4    2024-11-24  Instruction Impression               ProductInstructionPNA
# 5    2024-11-24  Instruction Impression               ProductInstructionPNA
# 6    2024-11-25  Instruction Impression               ProductInstructionPNA
# 7    2024-11-25  Instruction Impression               ProductInstructionPNA
#
#   custom_attributes__instruction_added custom_attributes__screen  n_events  \
# 0                               REMOVE                      Cart         1
# 1              REPLACE_WITH_BEST_MATCH                      Cart         1
# 2                               REMOVE                   PNA Hub        12
# 3              REPLACE_WITH_BEST_MATCH                   PNA Hub        12
# 4                               REMOVE                   PNA Hub        52
# 5              REPLACE_WITH_BEST_MATCH                   PNA Hub        52
# 6                               REMOVE                   PNA Hub        76
# 7              REPLACE_WITH_BEST_MATCH                   PNA Hub        76
#
#    n_customers
# 0            1
# 1            1
# 2            3
# 3            3
# 4            5
# 5            5
# 6           12
# 7           12

# %%
QUERY_NAME = 'instruction_added.sql'
START_DATE = "'2024-11-22'"
END_DATE = "'2024-11-25'"

params = [
    {'name':'start_date', 'value': str(START_DATE)},
    {'name':'end_date', 'value': str(END_DATE)}
]

q.prepare_query(
    QUERY_NAME
    ,params=params
    ,to_load_file=QUERY_NAME
    ,load_from_to_load_file=None
)

df  = q.query_run_starburst()
df
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/e28d23791c6e12adec9a7c5a9e482eccbc9c4ea83434bd645bd71ea4531c6e04
#   creation_date         event_name custom_attributes__instruction_type  \
# 0    2024-11-22  Instruction Added               ProductInstructionPNA
# 1    2024-11-22  Instruction Added               ProductInstructionPNA
# 2    2024-11-23  Instruction Added               ProductInstructionPNA
# 3    2024-11-23  Instruction Added               ProductInstructionPNA
# 4    2024-11-24  Instruction Added               ProductInstructionPNA
# 5    2024-11-24  Instruction Added               ProductInstructionPNA
# 6    2024-11-25  Instruction Added               ProductInstructionPNA
# 7    2024-11-25  Instruction Added               ProductInstructionPNA
# 8    2024-11-25  Instruction Added               ProductInstructionPNA
# 9    2024-11-25  Instruction Added               ProductInstructionPNA
#
#   custom_attributes__instruction_added   custom_attributes__screen  n_events  \
# 0                               REMOVE                     PNA Hub         4
# 1              REPLACE_WITH_BEST_MATCH                     PNA Hub         3
# 2                               REMOVE                     PNA Hub        15
# 3              REPLACE_WITH_BEST_MATCH                     PNA Hub         6
# 4                               REMOVE                     PNA Hub        14
# 5              REPLACE_WITH_BEST_MATCH                     PNA Hub         3
# 6                               REMOVE  Product Customization View         1
# 7                               REMOVE                     PNA Hub        27
# 8              REPLACE_WITH_BEST_MATCH  Product Customization View         1
# 9              REPLACE_WITH_BEST_MATCH                     PNA Hub         5
#
#    n_customers
# 0            2
# 1            2
# 2            5
# 3            1
# 4            2
# 5            1
# 6            1
# 7            6
# 8            1
# 9            1

# %%
QUERY_NAME = 'cart_loaded.sql'
START_DATE = "'2024-11-22'"
END_DATE = "'2024-11-25'"

params = [
    {'name':'start_date', 'value': str(START_DATE)},
    {'name':'end_date', 'value': str(END_DATE)}
]

q.prepare_query(
    QUERY_NAME
    ,params=params
    ,to_load_file=QUERY_NAME
    ,load_from_to_load_file=None
)

df  = q.query_run_starburst()
df
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/5e73d8113cf8b318e0df092d163fd7b67fe055803bc3b3dca516ad3168da822a
#   creation_date  event_name custom_attributes__cart_type  n_events  \
# 0    2024-11-22  CartLoaded                  ProductList    302535
# 1    2024-11-22  CartLoaded          ProductNotAvailable         8
# 2    2024-11-23  CartLoaded                  ProductList    350765
# 3    2024-11-23  CartLoaded          ProductNotAvailable        10
# 4    2024-11-24  CartLoaded                  ProductList    360519
# 5    2024-11-24  CartLoaded          ProductNotAvailable         8
# 6    2024-11-25  CartLoaded                  ProductList    124042
# 7    2024-11-25  CartLoaded          ProductNotAvailable        14
#
#    n_customers
# 0       168078
# 1            4
# 2       186525
# 3            5
# 4       192057
# 5            6
# 6        70648
# 7           12

# %%
QUERY_NAME = 'cart_interaction.sql'
START_DATE = "'2024-11-22'"
END_DATE = "'2024-11-25'"

params = [
    {'name':'start_date', 'value': str(START_DATE)},
    {'name':'end_date', 'value': str(END_DATE)}
]

q.prepare_query(
    QUERY_NAME
    ,params=params
    ,to_load_file=QUERY_NAME
    ,load_from_to_load_file=None
)

df  = q.query_run_starburst()
df
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/44c060c27dda8070e011fc372d2f3c2822d98a2f2dee9d530ab3efcf82aa3dec
#   creation_date       event_name custom_attributes__cart_interaction_type  \
# 0    2024-11-22  Cart Interacted                        GoPNAInstructions
# 1    2024-11-23  Cart Interacted                        GoPNAInstructions
# 2    2024-11-24  Cart Interacted                        GoPNAInstructions
# 3    2024-11-25  Cart Interacted                        GoPNAInstructions
#
#    n_events  n_customers
# 0         8            4
# 1        10            5
# 2         8            6
# 3        14           12
