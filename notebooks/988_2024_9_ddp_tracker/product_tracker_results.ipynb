# %% [markdown]
# # Product Tracker

# %%
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns
import sys

# Move two levels up (to the project root) and append the `src` folder
src_path = os.path.abspath(os.path.join(os.getcwd(), '..', '..'))

# Append src to sys.path
sys.path.append(src_path)

from src import query_engines

q = query_engines.QueryEngines()

# %%
DAYS_IN_ADVANCE = "8"

params = [
    {'name':'days_in_advance', 'value': DAYS_IN_ADVANCE},]

# %% [markdown]
# # Cart

# %% [markdown]
# ## Config

# %% [markdown]
# ## cart_loaded
#
# When the Cart Loaded screen is loaded
#
# <img src="images/cart_loaded.png" alt="cart_loaded" width="200"/>

# %%
#cart_loaded
q.prepare_query(query_file='events/cart_loaded.sql', params=params)

cart_loaded = q.query_run_starburst()

cart_loaded.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'cart_type'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/0f44fdd298ca0a31a5c6b3b1e557053cb42371b53b48e2af91b8c9e80a33cb9d
#   project_name p_creation_date  event_name    cart_type  count_event
# 4         cart      2024-09-20  CartLoaded  ProductList      1600638
# 5         cart      2024-09-21  CartLoaded  ProductList      1707483
# 6         cart      2024-09-22  CartLoaded  ProductList      1731231
# 0         cart      2024-09-23  CartLoaded  ProductList      1258893
# 7         cart      2024-09-24  CartLoaded  ProductList      1257994
# ...

# %% [markdown]
# ## cart_interacted
#
# When a product is impressed in the cart screen. There are 4 possible interactions
#
# <img src="images/cart_interacted.png" alt="cart_interacted" width="200"/>

# %%
#cart_interacted
q.prepare_query(query_file='events/cart_interacted.sql', params=params)

cart_interacted = q.query_run_starburst()

cart_interacted.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'cart_interaction_type'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/9715c3a7a45ef5af35320ab4c356fb1977cbf0f8abfb6a2751d1f28f7befcc3d
#    project_name p_creation_date       event_name     cart_interaction_type  \
# 8          cart      2024-09-20  Cart Interacted  AddRemoveQuantityClicked
# 13         cart      2024-09-20  Cart Interacted                    GoBack
# 4          cart      2024-09-20  Cart Interacted                GoCheckout
# 29         cart      2024-09-20  Cart Interacted      RemoveProductClicked
# ...

# %% [markdown]
# ## cart_interacted_is_addition
#
# When the user Adds or removes a quantity. But it is actually a '+'
#
# <img src="images/cart_interacted_is_addition.png" alt="cart_interacted_is_addition" width="200"/>

# %%
#cart_interacted_addition
q.prepare_query(query_file='events/cart_interacted_addition.sql', params=params)

cart_interacted_addition = q.query_run_starburst()

cart_interacted_addition.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'is_addition'
    ,'cart_interaction_type'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/cb496eb78f67a25b06b329602cd6f10987b31154acc90325c4a378ef69968c88
#    project_name p_creation_date       event_name is_addition  \
# 3          cart      2024-09-20  Cart Interacted       false
# 4          cart      2024-09-20  Cart Interacted        true
# 9          cart      2024-09-21  Cart Interacted       false
# 12         cart      2024-09-21  Cart Interacted        true
# 11         cart      2024-09-22  Cart Interacted       false
# 0          cart      2024-09-22  Cart Interacted        true
# ...

# %% [markdown]
# ## cart_product_impression
#
# When a product is impressed in the cart screen
#
# <img src="images/cart_product_impression.png" alt="cart_product_impression" width="200"/>

# %%
#cart_product_impression
q.prepare_query(query_file='events/cart_product_impression.sql', params=params)

cart_product_impression = q.query_run_starburst()

cart_product_impression.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'cart_type'
    ,'is_last_product'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/2f7b1061a323afbc81468bd20679a703a37592a41c7d614d8876b166d3b0c6e8
#    project_name p_creation_date               event_name    cart_type  \
# 3          cart      2024-09-20  Cart Product Impression  ProductList
# 0          cart      2024-09-20  Cart Product Impression  ProductList
# 9          cart      2024-09-21  Cart Product Impression  ProductList
# 1          cart      2024-09-21  Cart Product Impression  ProductList
# 11         cart      2024-09-22  Cart Product Impression  ProductList
# ...

# %% [markdown]
# ## product_selected
#
# When the user clicks removes a product from the cart. This requires tapping into the trash button, and later confirming
# the removal
#
# <img src="images/cart_product_selection.png" alt="cart_product_selection" width="200"/>

# %%
#product_selected
q.prepare_query(query_file='events/product_selected.sql', params=params)

product_selected = q.query_run_starburst()

product_selected.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'product_selected_origin'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/932ed5b7b07c9321fa588691cf64266f08c3e8649bb5393ddeea7134350ae7b8
#   project_name p_creation_date        event_name product_selected_origin  \
# 7         cart      2024-09-20  Product Selected                    Cart
# 2         cart      2024-09-21  Product Selected                    Cart
# 4         cart      2024-09-22  Product Selected                    Cart
# 5         cart      2024-09-23  Product Selected                    Cart
# 3         cart      2024-09-24  Product Selected                    Cart
# ...

# %% [markdown]
# ## product_added
#
# When the user click on the plus sign button.
#
# <img src="images/cart_product_added.png" alt="cart_product_added" width="200"/>

# %%
#product_added
q.prepare_query(query_file='events/product_added.sql', params=params)

product_added = q.query_run_starburst()

product_added.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'product_added_origin'
    ,'product_selected_origin'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/19afbc689e47c2cbe6f0c63eeebd1c928014a2b301cadd4d70568a69a0119c84
#   project_name p_creation_date             event_name product_added_origin  \
# 0         cart      2024-09-20  eCommerce - AddToCart                 Cart
# 1         cart      2024-09-21  eCommerce - AddToCart                 Cart
# 2         cart      2024-09-22  eCommerce - AddToCart                 Cart
# 3         cart      2024-09-23  eCommerce - AddToCart                 Cart
# ...

# %% [markdown]
# ## product_removed
#
# When the user clicks removes a product from the cart. This requires tapping into the trash button, and later confirming
# the removal
#
# <img src="images/cart_product_removed.png" alt="cart_product_removed" width="200"/>

# %%
#product_removed
q.prepare_query(query_file='events/product_removed.sql', params=params)

product_removed = q.query_run_starburst()

product_removed.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'product_removed_origin'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/b323ee28ad68d2feed1c7df5e7a2de8be91061a0eaf7b114763c71f16ac8d7e9
#   project_name p_creation_date                  event_name  \
# 7         cart      2024-09-20  eCommerce - RemoveFromCart
# 0         cart      2024-09-21  eCommerce - RemoveFromCart
# 4         cart      2024-09-22  eCommerce - RemoveFromCart
# 3         cart      2024-09-23  eCommerce - RemoveFromCart
# 6         cart      2024-09-24  eCommerce - RemoveFromCart
# 1         cart      2024-09-25  eCommerce - RemoveFromCart
# ...

# %% [markdown]
# # Loyalty Cards

# %% [markdown]
# ## bottom_sheet_interacted
#
# After clicking on the disconnect card button. A bottom sheet pops up. If I later click on the disconnect. It will be tracked
# here. But if it click son the go back, it is not tracked
#
# <img src="images/bottom_sheet_interacted.png" alt="bottom_sheet_interacted" width="200"/>

# %%
#bottom_sheet_interacted
q.prepare_query(query_file='events/bottom_sheet_interacted.sql', params=params)

bottom_sheet_interacted = q.query_run_starburst()

bottom_sheet_interacted.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'screen'
    ,'bottom_sheet_interaction_type'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/a33151f727dfd0d9cc983bbdcd28d00e9b71932731c6aa32fb9910a3359376af
#     project_name p_creation_date               event_name          screen  \
# 0  loyalty cards      2024-09-20  Bottom Sheet Interacted  LoyaltyProgram
# 3  loyalty cards      2024-09-21  Bottom Sheet Interacted  LoyaltyProgram
# 2  loyalty cards      2024-09-22  Bottom Sheet Interacted  LoyaltyProgram
# 5  loyalty cards      2024-09-23  Bottom Sheet Interacted  LoyaltyProgram
# 7  loyalty cards      2024-09-24  Bottom Sheet Interacted  LoyaltyProgram
# ...

# %% [markdown]
# ## bottom_sheet_shown
#
# Confirmation bottom sheet shown that appears when the customer wants to disconnect the card. This occurs after clicking
# the disconnect card button.
#
# <img src="images/bottom_sheet_shown.png" alt="bottom_sheet_shown" width="200"/>

# %%
#bottom_sheet_shown
q.prepare_query(query_file='events/bottom_sheet_shown.sql', params=params)

bottom_sheet_shown = q.query_run_starburst()

bottom_sheet_shown.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'source'
    ,'infoType'
    ,'screen'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/a5f77f2f015434a8bf60aa85f4fd7640ba5d3d26b350af71ca8fa0f0f6a05b5f
#     project_name p_creation_date          event_name      source  \
# 7  loyalty cards      2024-09-20  Bottom Sheet Shown  InfoButton
# 5  loyalty cards      2024-09-21  Bottom Sheet Shown  InfoButton
# 2  loyalty cards      2024-09-22  Bottom Sheet Shown  InfoButton
# 6  loyalty cards      2024-09-23  Bottom Sheet Shown  InfoButton
# 0  loyalty cards      2024-09-24  Bottom Sheet Shown  InfoButton
# ...

# %% [markdown]
# ## container_impression
#
# Container impression that contains the number of Loyalty Card if added
#
# <img src="images/container_impression.png" alt="container_impression" width="200"/>

# %%
#container_impression
q.prepare_query(query_file='events/container_impression.sql', params=params)

container_impression = q.query_run_starburst()

container_impression.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'container_app_location'
    ,'container_type'
    ,'is_loyalty_card_added'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/01d17b2da956069557ba831a56c8b0aebe4b4c4c9823bcc50640ca02d1cfaca6
#      project_name p_creation_date            event_name  \
# 38  loyalty cards      2024-09-20  Container Impression
# 0   loyalty cards      2024-09-20  Container Impression
# 2   loyalty cards      2024-09-20  Container Impression
# 8   loyalty cards      2024-09-20  Container Impression
# 35  loyalty cards      2024-09-20  Container Impression
# 10  loyalty cards      2024-09-21  Container Impression
# ...

# %% [markdown]
# ## order_created
#
# When the user places an order. We track if the order has Loyalty Cards details
#
# <img src="images/order_created.png" alt="order_created" width="200"/>

# %%
#order_created
q.prepare_query(query_file='events/order_created.sql', params=params)

order_created = q.query_run_starburst()

order_created.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'is_loyalty_card_added'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/6021ba78f357ca78474d817044d5abc2184481c88dae13576d8a9f7b41eb6178
#      project_name p_creation_date     event_name is_loyalty_card_added  \
# 10  loyalty cards      2024-09-20  Order Created                 false
# 7   loyalty cards      2024-09-20  Order Created                  true
# 13  loyalty cards      2024-09-21  Order Created                 false
# 15  loyalty cards      2024-09-21  Order Created                  true
# 2   loyalty cards      2024-09-22  Order Created                 false
# ...

# %% [markdown]
# ## store_membership_content_shown
#
# The screen of the Loyalty Membership is shown. Origins can span from Cart, Checkout, StoreDetails or Others
#
# <img src="images/store_membership_content_shown.png" alt="store_membership_content_shown" width="200"/>

# %%
#store_membership_content_shown
q.prepare_query(query_file='events/store_membership_content_shown.sql', params=params)

store_membership_content_shown = q.query_run_starburst()

store_membership_content_shown.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'origin'
    ,'is_loyalty_card_added'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/0561c9fb3a50d2cc23598a31fb01ff1ec2b871aef07d9acb1d481b3965163c81
#      project_name p_creation_date                      event_name  \
# 40  loyalty cards      2024-09-20  Store Membership Content Shown
# 11  loyalty cards      2024-09-20  Store Membership Content Shown
# 38  loyalty cards      2024-09-20  Store Membership Content Shown
# 19  loyalty cards      2024-09-20  Store Membership Content Shown
# 24  loyalty cards      2024-09-20  Store Membership Content Shown
# ...

# %% [markdown]
# ## store_membership_interacted
#
# 3 possible interactions in the Store Membership is being tracked. Join now is tracked as deeplink. And the others
# depend on the particular action of the button
#
# <img src="images/store_membership_interacted.png" alt="store_membership_interacted" width="200"/>

# %%
#store_membership_interacted
q.prepare_query(query_file='events/store_membership_interacted.sql', params=params)

store_membership_interacted = q.query_run_starburst()

store_membership_interacted.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'store_membership_interaction_type'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/0814703a90003b77811570792619a10e819f37b2e124b0b1f18b92c712689af1
#      project_name p_creation_date                   event_name  \
# 6   loyalty cards      2024-09-20  Store Membership Interacted
# 20  loyalty cards      2024-09-20  Store Membership Interacted
# 22  loyalty cards      2024-09-20  Store Membership Interacted
# 15  loyalty cards      2024-09-21  Store Membership Interacted
# 13  loyalty cards      2024-09-21  Store Membership Interacted
# 8   loyalty cards      2024-09-21  Store Membership Interacted
# ...

# %% [markdown]
# ## tooltip_impression
#
# The first time a user enters a store which they still had not seen the option of LC. Ten a tooltip is impressed
#
# <img src="images/tooltip_impression.png" alt="tooltip_impression" width="200"/>

# %%
#tooltip_impression
q.prepare_query(query_file='events/tooltip_impression.sql', params=params)

tooltip_impression = q.query_run_starburst()

tooltip_impression.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'tooltip_type'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/081b8241c3b166fced34401ead510dac6a5c33ebc916ead183662a450a94263f
#     project_name p_creation_date          event_name  tooltip_type  \
# 7  loyalty cards      2024-09-20  Tooltip Impression  LoyaltyCards
# 3  loyalty cards      2024-09-21  Tooltip Impression  LoyaltyCards
# 5  loyalty cards      2024-09-22  Tooltip Impression  LoyaltyCards
# 4  loyalty cards      2024-09-23  Tooltip Impression  LoyaltyCards
# 0  loyalty cards      2024-09-24  Tooltip Impression  LoyaltyCards
# ...

# %% [markdown]
# # Limiting Quantities

# %% [markdown]
# ## limiting_quantity_reached_sign
#
# After adding the + button quantity. Now the button turns into grey. That is because the limit was reached
#
# <img src="images/limiting_quantity_reached_sign.png" alt="limiting_quantity_reached_sign" width="200"/>

# %%
#limiting_quantity_reached_sign
q.prepare_query(query_file='events/limiting_quantity_reached_sign.sql', params=params)

limiting_quantity_reached_sign = q.query_run_starburst()

limiting_quantity_reached_sign.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/efb1f6742ee887d328dc5010bc706cff8509e21bf08e9f84efca5dad0e455d01
#           project_name p_creation_date                   event_name  \
# 0  limiting quantities      2024-09-20  Limit Quantity Reached Sign
# 3  limiting quantities      2024-09-21  Limit Quantity Reached Sign
# 1  limiting quantities      2024-09-22  Limit Quantity Reached Sign
# 2  limiting quantities      2024-09-23  Limit Quantity Reached Sign
# 4  limiting quantities      2024-09-24  Limit Quantity Reached Sign
# ...

# %% [markdown]
# ## snack_bar_shown
#
# After reaching the limit quanitty. When the user taps again on the grey + button. This
# triggers the Snack Bar Shown event
#
# <img src="images/snack_bar_shown.png" alt="snack_bar_shown" width="200"/>

# %%
#snack_bar_shown
q.prepare_query(query_file='events/snack_bar_shown.sql', params=params)

snack_bar_shown = q.query_run_starburst()

snack_bar_shown.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'snackbar_type'
    ,'quantity_limit_logic'
    ,'snackbar_screen'
])
# Out:
# /Users/jordicremades/Documents/repos/central-node/src/query_engines.py:138: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/a037c7e63374064facf1b237e4dff198beecdff1c729211cf8ac15bb7fa7b861
#            project_name p_creation_date      event_name         snackbar_type  \
# 9   limiting quantities      2024-09-20  Snackbar Shown  LimitQuantityReached
# 6   limiting quantities      2024-09-20  Snackbar Shown  LimitQuantityReached
# 15  limiting quantities      2024-09-21  Snackbar Shown  LimitQuantityReached
# 14  limiting quantities      2024-09-21  Snackbar Shown  LimitQuantityReached
# ...
