# %% [markdown]
# # DDP tracker

# %% [markdown]
# ## Config

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sys

sys.path.append('c:/Users/Jordi Cremades/Documents/Repos/central-node')

from src import query_engines

q = query_engines.QueryEngines()

# %% [markdown]
# ## Parameters

# %%
DAYS_IN_ADVANCE = "8"

params = [
    {'name':'days_in_advance', 'value': DAYS_IN_ADVANCE},]

# %% [markdown]
# ## Events tracker

# %% [markdown]
# ## snack_bar_shown

# %%
#limiting_quantity_reached_sign
q.prepare_query(query_file='events/limiting_quantity_reached_sign.sql', params=params)

limiting_quantity_reached_sign = q.query_run_starburst()

limiting_quantity_reached_sign.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#           project_name p_creation_date                   event_name  \
# 3  limiting quantities      2024-09-03  Limit Quantity Reached Sign
# 7  limiting quantities      2024-09-04  Limit Quantity Reached Sign
# 4  limiting quantities      2024-09-05  Limit Quantity Reached Sign
# 5  limiting quantities      2024-09-06  Limit Quantity Reached Sign
# 0  limiting quantities      2024-09-07  Limit Quantity Reached Sign
# 2  limiting quantities      2024-09-08  Limit Quantity Reached Sign
# 6  limiting quantities      2024-09-09  Limit Quantity Reached Sign
# 1  limiting quantities      2024-09-10  Limit Quantity Reached Sign
#
#    count_event  count_store_id  count_store_address_id  count_product_id  \
# 3         5551              77                     116              2570
# 7         5384              69                     108              2485
# 4         5351              71                     112              2468
# 5         5520              73                     115              2411
# 0         5261              72                     117              2442
# 2         6638              84                     130              3005
# 6         5893              69                     115              2685
# 1         5594              68                     105              2560
#
#    count_store_product_id
# 3                       8
# 7                      13
# 4                       4
# 5                       4
# 0                       1
# 2                       5
# 6                       1
# 1                       6

# %%
#snack_bar_shown
q.prepare_query(query_file='events/snack_bar_shown.sql', params=params)

snack_bar_shown = q.query_run_starburst()

snack_bar_shown.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'snackbar_type'
    ,'quantity_limit_logic'
    ,'snackbar_screen'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#            project_name p_creation_date      event_name         snackbar_type  \
# 14  limiting quantities      2024-09-03  Snackbar Shown  LimitQuantityReached
# 3   limiting quantities      2024-09-03  Snackbar Shown  LimitQuantityReached
# 13  limiting quantities      2024-09-04  Snackbar Shown  LimitQuantityReached
# 5   limiting quantities      2024-09-04  Snackbar Shown  LimitQuantityReached
# 7   limiting quantities      2024-09-05  Snackbar Shown  LimitQuantityReached
# 8   limiting quantities      2024-09-05  Snackbar Shown  LimitQuantityReached
# 1   limiting quantities      2024-09-06  Snackbar Shown  LimitQuantityReached
# 6   limiting quantities      2024-09-06  Snackbar Shown  LimitQuantityReached
# 11  limiting quantities      2024-09-07  Snackbar Shown  LimitQuantityReached
# 12  limiting quantities      2024-09-07  Snackbar Shown  LimitQuantityReached
# 9   limiting quantities      2024-09-08  Snackbar Shown  LimitQuantityReached
# 15  limiting quantities      2024-09-08  Snackbar Shown  LimitQuantityReached
# 4   limiting quantities      2024-09-09  Snackbar Shown  LimitQuantityReached
# 2   limiting quantities      2024-09-09  Snackbar Shown  LimitQuantityReached
# 0   limiting quantities      2024-09-10  Snackbar Shown  LimitQuantityReached
# 10  limiting quantities      2024-09-10  Snackbar Shown  LimitQuantityReached
#
#    quantity_limit_logic snackbar_screen  count_event  count_store_id  \
# 14            MAX_SALES            None           13               2
# 3          STOCK_AMOUNT            None         2189              56
# 13            MAX_SALES            None            9               2
# 5          STOCK_AMOUNT            None         1807              50
# 7             MAX_SALES            None           28               3
# 8          STOCK_AMOUNT            None         1622              50
# 1             MAX_SALES            None            4               2
# 6          STOCK_AMOUNT            None         1704              52
# 11            MAX_SALES            None           16               6
# 12         STOCK_AMOUNT            None         1351              49
# 9             MAX_SALES            None           49               5
# 15         STOCK_AMOUNT            None         1792              56
# 4             MAX_SALES            None           18               5
# 2          STOCK_AMOUNT            None         1493              48
# 0             MAX_SALES            None           19               4
# 10         STOCK_AMOUNT            None         1630              49
#
#     count_store_address_id  count_product_id  count_store_product_id
# 14                       4                 4                       3
# 3                       86               647                     572
# 13                       4                 4                       2
# 5                       77               622                     569
# 7                        6                 6                       1
# 8                       81               565                     510
# 1                        3                 3                       2
# 6                       81               625                     567
# 11                       7                 7                       2
# 12                      84               567                     526
# 9                        9                 9                       2
# 15                      88               714                     649
# 4                        8                10                       2
# 2                       74               647                     580
# 0                        7                 8                       3
# 10                      76               604                     544
