# %% [markdown]
# # DDP tracker

# %% [markdown]
# ## Config

# %%
import itertools
import matplotlib.pyplot as plt
import pandas as pd
import os
import seaborn as sns
import sys

sys.path.append('c:/Users/Jordi Cremades/Documents/Repos/central-node')

from utils import query_engines

# %% [markdown]
# ## Parameters

# %%
DAYS_IN_ADVANCE = "8"

params = [
    {'name':'days_in_advance', 'value': DAYS_IN_ADVANCE},
]

q = query_engines.QueryEngines(
    reset_query_logs=True
    ,reset_to_load=True
)

# %% [markdown]
# ## Events tracker

# %% [markdown]
# ## snack_bar_shown

# %%
#limiting_quantity_reached_sign
q.prepare_query('events/limiting_quantity_reached_sign.sql',params=params)
limiting_quantity_reached_sign = q.query_run_starburst(output_file='limiting_quantity_reached_sign',load_from_output_file=None,print_query=False)

limiting_quantity_reached_sign.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\utils\query_engines.py:235: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#           project_name p_creation_date                   event_name  \
# 3  limiting quantities      2024-09-02  Limit Quantity Reached Sign
# 4  limiting quantities      2024-09-03  Limit Quantity Reached Sign
# 2  limiting quantities      2024-09-04  Limit Quantity Reached Sign
# 1  limiting quantities      2024-09-05  Limit Quantity Reached Sign
# 5  limiting quantities      2024-09-06  Limit Quantity Reached Sign
# 0  limiting quantities      2024-09-07  Limit Quantity Reached Sign
# 7  limiting quantities      2024-09-08  Limit Quantity Reached Sign
# 6  limiting quantities      2024-09-09  Limit Quantity Reached Sign
#
# ...

# %%
#snack_bar_shown
q.prepare_query('events/snack_bar_shown.sql',params=params)
snack_bar_shown = q.query_run_starburst(output_file='snack_bar_shown',load_from_output_file=None,print_query=False)

snack_bar_shown.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'snackbar_type'
    ,'quantity_limit_logic'
    ,'snackbar_screen'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\utils\query_engines.py:235: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#            project_name p_creation_date      event_name         snackbar_type  \
# 9   limiting quantities      2024-09-02  Snackbar Shown  LimitQuantityReached
# 10  limiting quantities      2024-09-02  Snackbar Shown  LimitQuantityReached
# 14  limiting quantities      2024-09-03  Snackbar Shown  LimitQuantityReached
# 12  limiting quantities      2024-09-03  Snackbar Shown  LimitQuantityReached
# 5   limiting quantities      2024-09-04  Snackbar Shown  LimitQuantityReached
# 1   limiting quantities      2024-09-04  Snackbar Shown  LimitQuantityReached
# 15  limiting quantities      2024-09-05  Snackbar Shown  LimitQuantityReached
# ...
