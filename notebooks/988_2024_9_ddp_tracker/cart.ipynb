# %% [markdown]
# # Cart

# %% [markdown]
# ## Config

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sys

sys.path.append('c:/Users/Jordi Cremades/Documents/Repos/central-node')

from src import query_engines

q = query_engines.QueryEngines()

# %% [markdown]
# ## Parameters

# %%
DAYS_IN_ADVANCE = "8"

params = [
    {'name':'days_in_advance', 'value': DAYS_IN_ADVANCE},]

# %% [markdown]
# ## Events tracker

# %% [markdown]
# ## cart_loaded
#
# When the Cart Loaded screen is loaded
#
# <img src="outputs/cart_loaded.png" alt="cart_loaded" width="200"/>

# %%
#cart_loaded
q.prepare_query(query_file='events/cart_loaded.sql', params=params)

cart_loaded = q.query_run_starburst()

cart_loaded.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'cart_type'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#   project_name p_creation_date  event_name    cart_type  count_event
# 5         cart      2024-09-04  CartLoaded  ProductList      1347400
# 0         cart      2024-09-05  CartLoaded  ProductList      1376786
# 2         cart      2024-09-06  CartLoaded  ProductList      1544580
# 6         cart      2024-09-07  CartLoaded  ProductList      1601502
# 3         cart      2024-09-08  CartLoaded  ProductList      1703087
# 7         cart      2024-09-09  CartLoaded  ProductList      1310595
# 1         cart      2024-09-10  CartLoaded  ProductList      1324842
# 4         cart      2024-09-11  CartLoaded  ProductList      1361975

# %% [markdown]
# ## cart_interacted
#
# When a product is impressed in the cart screen. There are 4 possible interactions
#
# <img src="outputs/cart_interacted.png" alt="cart_interacted" width="200"/>

# %%
#cart_interacted
q.prepare_query(query_file='events/cart_interacted.sql', params=params)

cart_interacted = q.query_run_starburst()

cart_interacted.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'cart_interaction_type'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#    project_name p_creation_date       event_name     cart_interaction_type  \
# 3          cart      2024-09-04  Cart Interacted  AddRemoveQuantityClicked
# 19         cart      2024-09-04  Cart Interacted                    GoBack
# 5          cart      2024-09-04  Cart Interacted                GoCheckout
# 1          cart      2024-09-04  Cart Interacted      RemoveProductClicked
# 10         cart      2024-09-05  Cart Interacted  AddRemoveQuantityClicked
# 12         cart      2024-09-05  Cart Interacted                    GoBack
# 17         cart      2024-09-05  Cart Interacted                GoCheckout
# 25         cart      2024-09-05  Cart Interacted      RemoveProductClicked
# 29         cart      2024-09-06  Cart Interacted  AddRemoveQuantityClicked
# 7          cart      2024-09-06  Cart Interacted                    GoBack
# 24         cart      2024-09-06  Cart Interacted                GoCheckout
# 27         cart      2024-09-06  Cart Interacted      RemoveProductClicked
# 28         cart      2024-09-07  Cart Interacted  AddRemoveQuantityClicked
# 4          cart      2024-09-07  Cart Interacted                    GoBack
# 15         cart      2024-09-07  Cart Interacted                GoCheckout
# 8          cart      2024-09-07  Cart Interacted      RemoveProductClicked
# 14         cart      2024-09-08  Cart Interacted  AddRemoveQuantityClicked
# 16         cart      2024-09-08  Cart Interacted                    GoBack
# 21         cart      2024-09-08  Cart Interacted                GoCheckout
# 2          cart      2024-09-08  Cart Interacted      RemoveProductClicked
# 30         cart      2024-09-09  Cart Interacted  AddRemoveQuantityClicked
# 23         cart      2024-09-09  Cart Interacted                    GoBack
# 22         cart      2024-09-09  Cart Interacted                GoCheckout
# 11         cart      2024-09-09  Cart Interacted      RemoveProductClicked
# 6          cart      2024-09-10  Cart Interacted  AddRemoveQuantityClicked
# 0          cart      2024-09-10  Cart Interacted                    GoBack
# 26         cart      2024-09-10  Cart Interacted                GoCheckout
# 9          cart      2024-09-10  Cart Interacted      RemoveProductClicked
# 13         cart      2024-09-11  Cart Interacted  AddRemoveQuantityClicked
# 18         cart      2024-09-11  Cart Interacted                    GoBack
# 20         cart      2024-09-11  Cart Interacted                GoCheckout
# 31         cart      2024-09-11  Cart Interacted      RemoveProductClicked
#
#     count_event
# 3        202320
# 19       336563
# 5       1015758
# 1        218475
# 10       202002
# 12       342055
# 17      1035572
# 25       222571
# 29       228093
# 7        380598
# 24      1158224
# 27       248214
# 28       240419
# 4        406753
# 15      1184945
# 8        267873
# 14       237087
# 16       437799
# 21      1265463
# 2        277555
# 30       201296
# 23       329461
# 22       983023
# 11       217705
# 6        199799
# 0        330353
# 26       995705
# 9        218434
# 13       199719
# 18       337403
# 20      1022491
# 31       221147

# %% [markdown]
# ## cart_interacted_is_addition
#
# When the user Adds or removes a quantity. But it is actually a '+'
#
# <img src="outputs/cart_interacted_is_addition.png" alt="cart_interacted_is_addition" width="200"/>

# %%
#cart_interacted_addition
q.prepare_query(query_file='events/cart_interacted_addition.sql', params=params)

cart_interacted_addition = q.query_run_starburst()

cart_interacted_addition.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'is_addition'
    ,'cart_interaction_type'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#    project_name p_creation_date       event_name is_addition  \
# 4          cart      2024-09-04  Cart Interacted       false
# 10         cart      2024-09-04  Cart Interacted        true
# 8          cart      2024-09-05  Cart Interacted       false
# 2          cart      2024-09-05  Cart Interacted        true
# 1          cart      2024-09-06  Cart Interacted       false
# 6          cart      2024-09-06  Cart Interacted        true
# 9          cart      2024-09-07  Cart Interacted       false
# 13         cart      2024-09-07  Cart Interacted        true
# 11         cart      2024-09-08  Cart Interacted       false
# 14         cart      2024-09-08  Cart Interacted        true
# 3          cart      2024-09-09  Cart Interacted       false
# 7          cart      2024-09-09  Cart Interacted        true
# 0          cart      2024-09-10  Cart Interacted       false
# 5          cart      2024-09-10  Cart Interacted        true
# 15         cart      2024-09-11  Cart Interacted       false
# 12         cart      2024-09-11  Cart Interacted        true
#
#        cart_interaction_type  count_event
# 4   AddRemoveQuantityClicked       113694
# 10  AddRemoveQuantityClicked        88626
# 8   AddRemoveQuantityClicked       113455
# 2   AddRemoveQuantityClicked        88547
# 1   AddRemoveQuantityClicked       124948
# 6   AddRemoveQuantityClicked       103145
# 9   AddRemoveQuantityClicked       135301
# 13  AddRemoveQuantityClicked       105118
# 11  AddRemoveQuantityClicked       133449
# 14  AddRemoveQuantityClicked       103638
# 3   AddRemoveQuantityClicked       111113
# 7   AddRemoveQuantityClicked        90183
# 0   AddRemoveQuantityClicked       111557
# 5   AddRemoveQuantityClicked        88242
# 15  AddRemoveQuantityClicked       110145
# 12  AddRemoveQuantityClicked        89574

# %% [markdown]
# ## cart_product_impression
#
# When a product is impressed in the cart screen
#
# <img src="outputs/cart_product_impression.png" alt="cart_product_impression" width="200"/>

# %%
#cart_product_impression
q.prepare_query(query_file='events/cart_product_impression.sql', params=params)

cart_product_impression = q.query_run_starburst()

cart_product_impression.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'cart_type'
    ,'is_last_product'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#    project_name p_creation_date               event_name    cart_type  \
# 3          cart      2024-09-04  Cart Product Impression  ProductList
# 8          cart      2024-09-04  Cart Product Impression  ProductList
# 6          cart      2024-09-05  Cart Product Impression  ProductList
# 1          cart      2024-09-05  Cart Product Impression  ProductList
# 9          cart      2024-09-06  Cart Product Impression  ProductList
# 15         cart      2024-09-06  Cart Product Impression  ProductList
# 10         cart      2024-09-07  Cart Product Impression  ProductList
# 7          cart      2024-09-07  Cart Product Impression  ProductList
# 2          cart      2024-09-08  Cart Product Impression  ProductList
# 0          cart      2024-09-08  Cart Product Impression  ProductList
# 11         cart      2024-09-09  Cart Product Impression  ProductList
# 4          cart      2024-09-09  Cart Product Impression  ProductList
# 12         cart      2024-09-10  Cart Product Impression  ProductList
# 13         cart      2024-09-10  Cart Product Impression  ProductList
# 5          cart      2024-09-11  Cart Product Impression  ProductList
# 14         cart      2024-09-11  Cart Product Impression  ProductList
#
#    is_last_product  count_event
# 3            false      3200352
# 8             true      1359507
# 6            false      3214876
# 1             true      1390006
# 9            false      3578246
# 15            true      1560681
# 10           false      3970048
# 7             true      1619347
# 2            false      3775752
# 0             true      1722971
# 11           false      3304512
# 4             true      1319980
# 12           false      3244173
# 13            true      1336888
# 5            false      3216268
# 14            true      1374836

# %% [markdown]
# ## product_selected
#
# When the user clicks removes a product from the cart. This requires tapping into the trash button, and later confirming
# the removal
#
# <img src="outputs/cart_product_selection.png" alt="cart_product_selection" width="200"/>

# %%
#product_selected
q.prepare_query(query_file='events/product_selected.sql', params=params)

product_selected = q.query_run_starburst()

product_selected.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'product_selected_origin'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#   project_name p_creation_date        event_name product_selected_origin  \
# 7         cart      2024-09-04  Product Selected                    Cart
# 6         cart      2024-09-05  Product Selected                    Cart
# 5         cart      2024-09-06  Product Selected                    Cart
# 2         cart      2024-09-07  Product Selected                    Cart
# 0         cart      2024-09-08  Product Selected                    Cart
# 4         cart      2024-09-09  Product Selected                    Cart
# 3         cart      2024-09-10  Product Selected                    Cart
# 1         cart      2024-09-11  Product Selected                    Cart
#
#    count_event
# 7       223697
# 6       226982
# 5       263634
# 2       278961
# 0       283348
# 4       227472
# 3       224112
# 1       228687

# %% [markdown]
# ## product_added
#
# When the user click on the plus sign button.
#
# <img src="outputs/cart_product_added.png" alt="cart_product_added" width="200"/>

# %%
#product_added
q.prepare_query(query_file='events/product_added.sql', params=params)

product_added = q.query_run_starburst()

product_added.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'product_added_origin'
    ,'product_selected_origin'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#   project_name p_creation_date             event_name product_added_origin  \
# 7         cart      2024-09-04  eCommerce - AddToCart                 Cart
# 6         cart      2024-09-05  eCommerce - AddToCart                 Cart
# 5         cart      2024-09-06  eCommerce - AddToCart                 Cart
# 0         cart      2024-09-07  eCommerce - AddToCart                 Cart
# 2         cart      2024-09-08  eCommerce - AddToCart                 Cart
# 1         cart      2024-09-09  eCommerce - AddToCart                 Cart
# 4         cart      2024-09-10  eCommerce - AddToCart                 Cart
# 3         cart      2024-09-11  eCommerce - AddToCart                 Cart
#
#   product_selected_origin  count_event
# 7                    Cart        86054
# 6                    Cart        85538
# 5                    Cart        99959
# 0                    Cart       102098
# 2                    Cart       100289
# 1                    Cart        87627
# 4                    Cart        85537
# 3                    Cart        86687

# %% [markdown]
# ## product_removed
#
# When the user clicks removes a product from the cart. This requires tapping into the trash button, and later confirming
# the removal
#
# <img src="outputs/cart_product_removed.png" alt="cart_product_removed" width="200"/>

# %%
#product_removed
q.prepare_query(query_file='events/product_removed.sql', params=params)

product_removed = q.query_run_starburst()

product_removed.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'product_removed_origin'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#   project_name p_creation_date                  event_name  \
# 0         cart      2024-09-04  eCommerce - RemoveFromCart
# 1         cart      2024-09-05  eCommerce - RemoveFromCart
# 5         cart      2024-09-06  eCommerce - RemoveFromCart
# 2         cart      2024-09-07  eCommerce - RemoveFromCart
# 3         cart      2024-09-08  eCommerce - RemoveFromCart
# 4         cart      2024-09-09  eCommerce - RemoveFromCart
# 6         cart      2024-09-10  eCommerce - RemoveFromCart
# 7         cart      2024-09-11  eCommerce - RemoveFromCart
#
#   product_removed_origin  count_event
# 0      Cart Minus Button       171201
# 1      Cart Minus Button       170433
# 5      Cart Minus Button       187886
# 2      Cart Minus Button       202656
# 3      Cart Minus Button       202662
# 4      Cart Minus Button       172092
# 6      Cart Minus Button       170310
# 7      Cart Minus Button       169707
