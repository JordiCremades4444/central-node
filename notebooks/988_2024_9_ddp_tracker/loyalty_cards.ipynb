# %% [markdown]
# # Loyalty Cards

# %% [markdown]
# ## Config

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import sys

sys.path.append('c:/Users/Jordi Cremades/Documents/Repos/central-node')

from src import query_engines

q = query_engines.QueryEngines()

# %% [markdown]
# ## Parameters

# %%
DAYS_IN_ADVANCE = "8"

params = [
    {'name':'days_in_advance', 'value': DAYS_IN_ADVANCE},]

# %% [markdown]
# ## Events tracker

# %% [markdown]
# ## bottom_sheet_interacted
#
# After clicking on the disconnect card button. A bottom sheet pops up. If I later click on the disconnect. It will be tracked
# here. But if it click son the go back, it is not tracked
#
# <img src="images/bottom_sheet_interacted.png" alt="bottom_sheet_interacted" width="200"/>

# %%
#bottom_sheet_interacted
q.prepare_query(query_file='events/bottom_sheet_interacted.sql', params=params)

bottom_sheet_interacted = q.query_run_starburst()

bottom_sheet_interacted.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'screen'
    ,'bottom_sheet_interaction_type'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#     project_name p_creation_date               event_name          screen  \
# 2  loyalty cards      2024-09-03  Bottom Sheet Interacted  LoyaltyProgram
# 3  loyalty cards      2024-09-04  Bottom Sheet Interacted  LoyaltyProgram
# 5  loyalty cards      2024-09-05  Bottom Sheet Interacted  LoyaltyProgram
# 7  loyalty cards      2024-09-06  Bottom Sheet Interacted  LoyaltyProgram
# 0  loyalty cards      2024-09-07  Bottom Sheet Interacted  LoyaltyProgram
# 4  loyalty cards      2024-09-08  Bottom Sheet Interacted  LoyaltyProgram
# 1  loyalty cards      2024-09-09  Bottom Sheet Interacted  LoyaltyProgram
# 6  loyalty cards      2024-09-10  Bottom Sheet Interacted  LoyaltyProgram
#
#   bottom_sheet_interaction_type  count_event  count_store_id
# 2   DisconnectLoyaltyMembership           20              16
# 3   DisconnectLoyaltyMembership            9               8
# 5   DisconnectLoyaltyMembership           19              13
# 7   DisconnectLoyaltyMembership           14              11
# 0   DisconnectLoyaltyMembership           11               6
# 4   DisconnectLoyaltyMembership           24              20
# 1   DisconnectLoyaltyMembership           16              12
# 6   DisconnectLoyaltyMembership           10               6

# %% [markdown]
# ## bottom_sheet_shown
#
# Confirmation bottom sheet shown that appears when the customer wants to disconnect the card. This occurs after clicking
# the disconnect card button.
#
# <img src="images/bottom_sheet_shown.png" alt="bottom_sheet_shown" width="200"/>

# %%
#bottom_sheet_shown
q.prepare_query(query_file='events/bottom_sheet_shown.sql', params=params)

bottom_sheet_shown = q.query_run_starburst()

bottom_sheet_shown.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'source'
    ,'infoType'
    ,'screen'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#     project_name p_creation_date          event_name      source  \
# 6  loyalty cards      2024-09-03  Bottom Sheet Shown  InfoButton
# 0  loyalty cards      2024-09-04  Bottom Sheet Shown  InfoButton
# 5  loyalty cards      2024-09-05  Bottom Sheet Shown  InfoButton
# 2  loyalty cards      2024-09-06  Bottom Sheet Shown  InfoButton
# 7  loyalty cards      2024-09-07  Bottom Sheet Shown  InfoButton
# 1  loyalty cards      2024-09-08  Bottom Sheet Shown  InfoButton
# 3  loyalty cards      2024-09-09  Bottom Sheet Shown  InfoButton
# 4  loyalty cards      2024-09-10  Bottom Sheet Shown  InfoButton
#
#                     infoType          screen  count_event  count_store_id
# 6  StoreMembershipDisconnect  LoyaltyProgram           23              18
# 0  StoreMembershipDisconnect  LoyaltyProgram           12              12
# 5  StoreMembershipDisconnect  LoyaltyProgram           24              16
# 2  StoreMembershipDisconnect  LoyaltyProgram           16              13
# 7  StoreMembershipDisconnect  LoyaltyProgram           13               7
# 1  StoreMembershipDisconnect  LoyaltyProgram           26              21
# 3  StoreMembershipDisconnect  LoyaltyProgram           21              17
# 4  StoreMembershipDisconnect  LoyaltyProgram           13               9

# %% [markdown]
# ## container_impression
#
# Container impression that contains the number of Loyalty Card if added
#
# <img src="images/container_impression.png" alt="container_impression" width="200"/>

# %%
#container_impression
q.prepare_query(query_file='events/container_impression.sql', params=params)

container_impression = q.query_run_starburst()

container_impression.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'container_app_location'
    ,'container_type'
    ,'is_loyalty_card_added'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#      project_name p_creation_date            event_name  \
# 33  loyalty cards      2024-09-03  Container Impression
# 23  loyalty cards      2024-09-03  Container Impression
# 32  loyalty cards      2024-09-03  Container Impression
# 26  loyalty cards      2024-09-03  Container Impression
# 37  loyalty cards      2024-09-03  Container Impression
# 0   loyalty cards      2024-09-04  Container Impression
# 31  loyalty cards      2024-09-04  Container Impression
# 39  loyalty cards      2024-09-04  Container Impression
# 36  loyalty cards      2024-09-04  Container Impression
# 17  loyalty cards      2024-09-04  Container Impression
# 9   loyalty cards      2024-09-05  Container Impression
# 25  loyalty cards      2024-09-05  Container Impression
# 10  loyalty cards      2024-09-05  Container Impression
# 27  loyalty cards      2024-09-05  Container Impression
# 30  loyalty cards      2024-09-05  Container Impression
# 8   loyalty cards      2024-09-06  Container Impression
# 28  loyalty cards      2024-09-06  Container Impression
# 29  loyalty cards      2024-09-06  Container Impression
# 21  loyalty cards      2024-09-06  Container Impression
# 7   loyalty cards      2024-09-06  Container Impression
# 19  loyalty cards      2024-09-07  Container Impression
# 22  loyalty cards      2024-09-07  Container Impression
# 14  loyalty cards      2024-09-07  Container Impression
# 24  loyalty cards      2024-09-07  Container Impression
# 2   loyalty cards      2024-09-07  Container Impression
# 13  loyalty cards      2024-09-08  Container Impression
# 3   loyalty cards      2024-09-08  Container Impression
# 6   loyalty cards      2024-09-08  Container Impression
# 40  loyalty cards      2024-09-08  Container Impression
# 16  loyalty cards      2024-09-08  Container Impression
# 18  loyalty cards      2024-09-09  Container Impression
# 4   loyalty cards      2024-09-09  Container Impression
# 5   loyalty cards      2024-09-09  Container Impression
# 35  loyalty cards      2024-09-09  Container Impression
# 11  loyalty cards      2024-09-09  Container Impression
# 20  loyalty cards      2024-09-10  Container Impression
# 1   loyalty cards      2024-09-10  Container Impression
# 38  loyalty cards      2024-09-10  Container Impression
# 15  loyalty cards      2024-09-10  Container Impression
# 12  loyalty cards      2024-09-10  Container Impression
# 34  loyalty cards      2024-09-10  Container Impression
#
#    container_app_location container_type is_loyalty_card_added  count_event  \
# 33                   Cart   LoyaltyCards                 false        20101
# 23               Checkout   LoyaltyCards                 false         9871
# 32               Checkout   LoyaltyCards                  true         2361
# 26             store-view   LoyaltyCards                 false        92993
# 37             store-view   LoyaltyCards                  true        16637
# 0                    Cart   LoyaltyCards                 false        17986
# 31               Checkout   LoyaltyCards                 false         9180
# 39               Checkout   LoyaltyCards                  true         2141
# 36             store-view   LoyaltyCards                 false        90937
# 17             store-view   LoyaltyCards                  true        16289
# 9                    Cart   LoyaltyCards                 false        19127
# 25               Checkout   LoyaltyCards                 false         9431
# 10               Checkout   LoyaltyCards                  true         2389
# 27             store-view   LoyaltyCards                 false        91864
# 30             store-view   LoyaltyCards                  true        17037
# 8                    Cart   LoyaltyCards                 false        19472
# 28               Checkout   LoyaltyCards                 false         9891
# 29               Checkout   LoyaltyCards                  true         2503
# 21             store-view   LoyaltyCards                 false        93726
# 7              store-view   LoyaltyCards                  true        18752
# 19                   Cart   LoyaltyCards                 false        22456
# 22               Checkout   LoyaltyCards                 false        11091
# 14               Checkout   LoyaltyCards                  true         2645
# 24             store-view   LoyaltyCards                 false       108474
# 2              store-view   LoyaltyCards                  true        19362
# 13                   Cart   LoyaltyCards                 false        18971
# 3                Checkout   LoyaltyCards                 false         9509
# 6                Checkout   LoyaltyCards                  true         2391
# 40             store-view   LoyaltyCards                 false       100330
# 16             store-view   LoyaltyCards                  true        18020
# 18                   Cart   LoyaltyCards                 false        18186
# 4                Checkout   LoyaltyCards                 false         9239
# 5                Checkout   LoyaltyCards                  true         2374
# 35             store-view   LoyaltyCards                 false        92620
# 11             store-view   LoyaltyCards                  true        17257
# 20                   Cart   LoyaltyCards                 false        19280
# 1                Checkout   LoyaltyCards                 false         9625
# 38               Checkout   LoyaltyCards                  true         2583
# 15             store-view   LoyaltyCards                 false        93533
# 12             store-view   LoyaltyCards                  true        18084
# 34                   None     AddVoucher                  None            2
#
#     count_store_id
# 33             503
# 23             483
# 32             362
# 26             557
# 37             420
# 0              497
# 31             480
# 39             329
# 36             554
# 17             409
# 9              488
# 25             478
# 10             346
# 27             553
# 30             410
# 8              504
# 28             489
# 29             356
# 21             564
# 7              434
# 19             502
# 22             487
# 14             362
# 24             558
# 2              441
# 13             418
# 3              398
# 6              287
# 40             554
# 16             351
# 18             483
# 4              466
# 5              328
# 35             563
# 11             409
# 20             493
# 1              482
# 38             338
# 15             555
# 12             409
# 34               1

# %% [markdown]
# ## order_created
#
# When the user places an order. We track if the order has Loyalty Cards details
#
# <img src="images/order_created.png" alt="order_created" width="200"/>

# %%
#order_created
q.prepare_query(query_file='events/order_created.sql', params=params)

order_created = q.query_run_starburst()

order_created.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'is_loyalty_card_added'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#      project_name p_creation_date     event_name is_loyalty_card_added  \
# 14  loyalty cards      2024-09-03  Order Created                 false
# 7   loyalty cards      2024-09-03  Order Created                  true
# 8   loyalty cards      2024-09-04  Order Created                 false
# 3   loyalty cards      2024-09-04  Order Created                  true
# 11  loyalty cards      2024-09-05  Order Created                 false
# 15  loyalty cards      2024-09-05  Order Created                  true
# 9   loyalty cards      2024-09-06  Order Created                 false
# 4   loyalty cards      2024-09-06  Order Created                  true
# 12  loyalty cards      2024-09-07  Order Created                 false
# 0   loyalty cards      2024-09-07  Order Created                  true
# 2   loyalty cards      2024-09-08  Order Created                 false
# 6   loyalty cards      2024-09-08  Order Created                  true
# 13  loyalty cards      2024-09-09  Order Created                 false
# 1   loyalty cards      2024-09-09  Order Created                  true
# 10  loyalty cards      2024-09-10  Order Created                 false
# 5   loyalty cards      2024-09-10  Order Created                  true
#
#     count_event
# 14         4667
# 7          1124
# 8          4993
# 3          1186
# 11         4520
# 15         1200
# 9          4707
# 4          1246
# 12         5221
# 0          1251
# 2          4571
# 6          1129
# 13         4541
# 1          1174
# 10         4641
# 5          1258

# %% [markdown]
# ## store_membership_content_shown
#
# The screen of the Loyalty Membership is shown. Origins can span from Cart, Checkout, StoreDetails or Others
#
# <img src="images/store_membership_content_shown.png" alt="store_membership_content_shown" width="200"/>

# %%
#store_membership_content_shown
q.prepare_query(query_file='events/store_membership_content_shown.sql', params=params)

store_membership_content_shown = q.query_run_starburst()

store_membership_content_shown.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'origin'
    ,'is_loyalty_card_added'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#      project_name p_creation_date                      event_name  \
# 11  loyalty cards      2024-09-03  Store Membership Content Shown
# 20  loyalty cards      2024-09-03  Store Membership Content Shown
# 10  loyalty cards      2024-09-03  Store Membership Content Shown
# 49  loyalty cards      2024-09-03  Store Membership Content Shown
# 17  loyalty cards      2024-09-03  Store Membership Content Shown
# 23  loyalty cards      2024-09-03  Store Membership Content Shown
# 53  loyalty cards      2024-09-03  Store Membership Content Shown
# 2   loyalty cards      2024-09-04  Store Membership Content Shown
# 21  loyalty cards      2024-09-04  Store Membership Content Shown
# 25  loyalty cards      2024-09-04  Store Membership Content Shown
# 51  loyalty cards      2024-09-04  Store Membership Content Shown
# 1   loyalty cards      2024-09-04  Store Membership Content Shown
# 3   loyalty cards      2024-09-04  Store Membership Content Shown
# 29  loyalty cards      2024-09-04  Store Membership Content Shown
# 31  loyalty cards      2024-09-05  Store Membership Content Shown
# 18  loyalty cards      2024-09-05  Store Membership Content Shown
# 16  loyalty cards      2024-09-05  Store Membership Content Shown
# 26  loyalty cards      2024-09-05  Store Membership Content Shown
# 7   loyalty cards      2024-09-05  Store Membership Content Shown
# 5   loyalty cards      2024-09-05  Store Membership Content Shown
# 39  loyalty cards      2024-09-05  Store Membership Content Shown
# 35  loyalty cards      2024-09-06  Store Membership Content Shown
# 30  loyalty cards      2024-09-06  Store Membership Content Shown
# 40  loyalty cards      2024-09-06  Store Membership Content Shown
# 37  loyalty cards      2024-09-06  Store Membership Content Shown
# 22  loyalty cards      2024-09-06  Store Membership Content Shown
# 9   loyalty cards      2024-09-06  Store Membership Content Shown
# 6   loyalty cards      2024-09-06  Store Membership Content Shown
# 43  loyalty cards      2024-09-07  Store Membership Content Shown
# 12  loyalty cards      2024-09-07  Store Membership Content Shown
# 19  loyalty cards      2024-09-07  Store Membership Content Shown
# 47  loyalty cards      2024-09-07  Store Membership Content Shown
# 38  loyalty cards      2024-09-07  Store Membership Content Shown
# 0   loyalty cards      2024-09-07  Store Membership Content Shown
# 33  loyalty cards      2024-09-07  Store Membership Content Shown
# 36  loyalty cards      2024-09-08  Store Membership Content Shown
# 34  loyalty cards      2024-09-08  Store Membership Content Shown
# 14  loyalty cards      2024-09-08  Store Membership Content Shown
# 52  loyalty cards      2024-09-08  Store Membership Content Shown
# 46  loyalty cards      2024-09-08  Store Membership Content Shown
# 48  loyalty cards      2024-09-08  Store Membership Content Shown
# 41  loyalty cards      2024-09-08  Store Membership Content Shown
# 27  loyalty cards      2024-09-09  Store Membership Content Shown
# 8   loyalty cards      2024-09-09  Store Membership Content Shown
# 50  loyalty cards      2024-09-09  Store Membership Content Shown
# 42  loyalty cards      2024-09-09  Store Membership Content Shown
# 28  loyalty cards      2024-09-09  Store Membership Content Shown
# 24  loyalty cards      2024-09-09  Store Membership Content Shown
# 32  loyalty cards      2024-09-10  Store Membership Content Shown
# 45  loyalty cards      2024-09-10  Store Membership Content Shown
# 15  loyalty cards      2024-09-10  Store Membership Content Shown
# 44  loyalty cards      2024-09-10  Store Membership Content Shown
# 4   loyalty cards      2024-09-10  Store Membership Content Shown
# 13  loyalty cards      2024-09-10  Store Membership Content Shown
#
#           origin is_loyalty_card_added  count_event  count_store_id
# 11          Cart                 false          478             204
# 20      Checkout                 false          245             133
# 10      Checkout                  true          137              75
# 49         Other                 false           17              13
# 17         Other                  true            3               3
# 23  StoreDetails                 false          848             255
# 53  StoreDetails                  true          100              57
# 2           Cart                 false          492             198
# 21      Checkout                 false          190             112
# 25      Checkout                  true          120              72
# 51         Other                 false           14               9
# 1          Other                  true            1               1
# 3   StoreDetails                 false          792             253
# 29  StoreDetails                  true          108              58
# 31          Cart                 false          451             179
# 18      Checkout                 false          224             114
# 16      Checkout                  true          123              76
# 26         Other                 false           14              12
# 7          Other                  true            6               2
# 5   StoreDetails                 false          818             265
# 39  StoreDetails                  true          110              61
# 35          Cart                 false          418             187
# 30      Checkout                 false          237             125
# 40      Checkout                  true          123              70
# 37         Other                 false            9               9
# 22         Other                  true            1               1
# 9   StoreDetails                 false          793             257
# 6   StoreDetails                  true          103              59
# 43          Cart                 false          582             213
# 12      Checkout                 false          313             149
# 19      Checkout                  true          135              79
# 47         Other                 false           16              15
# 38         Other                  true            3               2
# 0   StoreDetails                 false          883             287
# 33  StoreDetails                  true          118              77
# 36          Cart                 false          488             161
# 34      Checkout                 false          242             108
# 14      Checkout                  true          141              70
# 52         Other                 false           11               9
# 46         Other                  true            2               1
# 48  StoreDetails                 false          951             245
# 41  StoreDetails                  true          113              67
# 27          Cart                 false          392             163
# 8       Checkout                 false          229             121
# 50      Checkout                  true          144              79
# 42         Other                 false            9               6
# 28  StoreDetails                 false          761             241
# 24  StoreDetails                  true          106              61
# 32          Cart                 false          443             197
# 45      Checkout                 false          226             126
# 15      Checkout                  true          133              71
# 44         Other                 false           10               8
# 4   StoreDetails                 false          806             265
# 13  StoreDetails                  true          112              65

# %% [markdown]
# ## store_membership_interacted
#
# 3 possible interactions in the Store Membership is being tracked. Join now is tracked as deeplink. And the others
# depend on the particular action of the button
#
# <img src="images/store_membership_interacted.png" alt="store_membership_interacted" width="200"/>

# %%
#store_membership_interacted
q.prepare_query(query_file='events/store_membership_interacted.sql', params=params)

store_membership_interacted = q.query_run_starburst()

store_membership_interacted.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'store_membership_interaction_type'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#      project_name p_creation_date                   event_name  \
# 4   loyalty cards      2024-09-03  Store Membership Interacted
# 11  loyalty cards      2024-09-03  Store Membership Interacted
# 8   loyalty cards      2024-09-03  Store Membership Interacted
# 14  loyalty cards      2024-09-04  Store Membership Interacted
# 9   loyalty cards      2024-09-04  Store Membership Interacted
# 16  loyalty cards      2024-09-04  Store Membership Interacted
# 5   loyalty cards      2024-09-05  Store Membership Interacted
# 2   loyalty cards      2024-09-05  Store Membership Interacted
# 10  loyalty cards      2024-09-05  Store Membership Interacted
# 21  loyalty cards      2024-09-06  Store Membership Interacted
# 12  loyalty cards      2024-09-06  Store Membership Interacted
# 15  loyalty cards      2024-09-06  Store Membership Interacted
# 22  loyalty cards      2024-09-07  Store Membership Interacted
# 1   loyalty cards      2024-09-07  Store Membership Interacted
# 19  loyalty cards      2024-09-07  Store Membership Interacted
# 7   loyalty cards      2024-09-08  Store Membership Interacted
# 6   loyalty cards      2024-09-08  Store Membership Interacted
# 23  loyalty cards      2024-09-08  Store Membership Interacted
# 13  loyalty cards      2024-09-09  Store Membership Interacted
# 3   loyalty cards      2024-09-09  Store Membership Interacted
# 20  loyalty cards      2024-09-09  Store Membership Interacted
# 17  loyalty cards      2024-09-10  Store Membership Interacted
# 0   loyalty cards      2024-09-10  Store Membership Interacted
# 18  loyalty cards      2024-09-10  Store Membership Interacted
#
#    store_membership_interaction_type  count_event  count_store_id
# 4                            confirm          726             230
# 11                          deeplink          161              81
# 8                  disconnectAccount           24              18
# 14                           confirm          888             227
# 9                           deeplink          171              95
# 16                 disconnectAccount           14              12
# 5                            confirm          666             215
# 2                           deeplink          130              74
# 10                 disconnectAccount           24              16
# 21                           confirm          641             209
# 12                          deeplink          133              74
# 15                 disconnectAccount           16              13
# 22                           confirm          757             245
# 1                           deeplink          167              86
# 19                 disconnectAccount           13               7
# 7                            confirm          754             204
# 6                           deeplink          162              88
# 23                 disconnectAccount           27              21
# 13                           confirm          589             193
# 3                           deeplink          135              71
# 20                 disconnectAccount           21              17
# 17                           confirm          670             212
# 0                           deeplink          153              80
# 18                 disconnectAccount           14               9

# %% [markdown]
# ## tooltip_impression
#
# The first time a user enters a store which they still had not seen the option of LC. Ten a tooltip is impressed
#
# <img src="images/tooltip_impression.png" alt="tooltip_impression" width="200"/>

# %%
#tooltip_impression
q.prepare_query(query_file='events/tooltip_impression.sql', params=params)

tooltip_impression = q.query_run_starburst()

tooltip_impression.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'tooltip_type'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\src\query_engines.py:197: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#     project_name p_creation_date          event_name  tooltip_type  \
# 0  loyalty cards      2024-09-03  Tooltip Impression  LoyaltyCards
# 4  loyalty cards      2024-09-04  Tooltip Impression  LoyaltyCards
# 5  loyalty cards      2024-09-05  Tooltip Impression  LoyaltyCards
# 1  loyalty cards      2024-09-06  Tooltip Impression  LoyaltyCards
# 7  loyalty cards      2024-09-07  Tooltip Impression  LoyaltyCards
# 6  loyalty cards      2024-09-08  Tooltip Impression  LoyaltyCards
# 2  loyalty cards      2024-09-09  Tooltip Impression  LoyaltyCards
# 3  loyalty cards      2024-09-10  Tooltip Impression  LoyaltyCards
#
#    count_event
# 0        15932
# 4        15712
# 5        15936
# 1        17216
# 7        20386
# 6        19552
# 2        15425
# 3        16285
