# %% [markdown]
# # Loyalty Cards

# %% [markdown]
# ## Config

# %%
import itertools
import matplotlib.pyplot as plt
import pandas as pd
import os
import seaborn as sns
import sys

sys.path.append('c:/Users/Jordi Cremades/Documents/Repos/central-node')

from utils import query_engines

# %% [markdown]
# ## Parameters

# %%
DAYS_IN_ADVANCE = "8"

params = [
    {'name':'days_in_advance', 'value': DAYS_IN_ADVANCE},
]

q = query_engines.QueryEngines(
    reset_query_logs=True
    ,reset_to_load=True
)

# %% [markdown]
# ## Events tracker

# %% [markdown]
# ## snack_bar_shown

# %%
#bottom_sheet_interacted
q.prepare_query('events/bottom_sheet_interacted.sql',params=params)
bottom_sheet_interacted = q.query_run_starburst(output_file='bottom_sheet_interacted',load_from_output_file=None,print_query=False)

bottom_sheet_interacted.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'screen'
    ,'bottom_sheet_interaction_type'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\utils\query_engines.py:235: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#     project_name p_creation_date               event_name          screen  \
# 4  loyalty cards      2024-09-02  Bottom Sheet Interacted  LoyaltyProgram
# 7  loyalty cards      2024-09-03  Bottom Sheet Interacted  LoyaltyProgram
# 5  loyalty cards      2024-09-04  Bottom Sheet Interacted  LoyaltyProgram
# 3  loyalty cards      2024-09-05  Bottom Sheet Interacted  LoyaltyProgram
# 2  loyalty cards      2024-09-06  Bottom Sheet Interacted  LoyaltyProgram
# 1  loyalty cards      2024-09-07  Bottom Sheet Interacted  LoyaltyProgram
# 6  loyalty cards      2024-09-08  Bottom Sheet Interacted  LoyaltyProgram
# ...

# %% [markdown]
# ## bottom_sheet_shown

# %%
#bottom_sheet_shown
q.prepare_query('events/bottom_sheet_shown.sql',params=params)
bottom_sheet_shown = q.query_run_starburst(output_file='bottom_sheet_shown',load_from_output_file=None,print_query=False)

bottom_sheet_shown.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'source'
    ,'infoType'
    ,'screen'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\utils\query_engines.py:235: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#     project_name p_creation_date          event_name      source  \
# 1  loyalty cards      2024-09-02  Bottom Sheet Shown  InfoButton
# 4  loyalty cards      2024-09-03  Bottom Sheet Shown  InfoButton
# 0  loyalty cards      2024-09-04  Bottom Sheet Shown  InfoButton
# 2  loyalty cards      2024-09-05  Bottom Sheet Shown  InfoButton
# 6  loyalty cards      2024-09-06  Bottom Sheet Shown  InfoButton
# 7  loyalty cards      2024-09-07  Bottom Sheet Shown  InfoButton
# 5  loyalty cards      2024-09-08  Bottom Sheet Shown  InfoButton
# 3  loyalty cards      2024-09-09  Bottom Sheet Shown  InfoButton
#
# ...

# %% [markdown]
# ## container_impression

# %%
#container_impression
q.prepare_query('events/container_impression.sql',params=params)
bottom_sheet_interacted  = q.query_run_starburst(output_file='container_impression',load_from_output_file=None,print_query=False)

bottom_sheet_interacted.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'container_app_location'
    ,'container_type'
    ,'is_loyalty_card_added'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\utils\query_engines.py:235: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#      project_name p_creation_date            event_name  \
# 7   loyalty cards      2024-09-02  Container Impression
# 9   loyalty cards      2024-09-02  Container Impression
# 6   loyalty cards      2024-09-03  Container Impression
# 10  loyalty cards      2024-09-03  Container Impression
# 0   loyalty cards      2024-09-04  Container Impression
# 4   loyalty cards      2024-09-04  Container Impression
# 8   loyalty cards      2024-09-05  Container Impression
# 3   loyalty cards      2024-09-05  Container Impression
# 2   loyalty cards      2024-09-06  Container Impression
# 5   loyalty cards      2024-09-06  Container Impression
# ...

# %% [markdown]
# ## order_created

# %%
#order_created
q.prepare_query('events/order_created.sql',params=params)
order_created = q.query_run_starburst(output_file='order_created',load_from_output_file=None,print_query=False)

order_created.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'is_loyalty_card_added'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\utils\query_engines.py:235: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#      project_name p_creation_date     event_name is_loyalty_card_added  \
# 5   loyalty cards      2024-09-02  Order Created                 false
# 1   loyalty cards      2024-09-02  Order Created                  true
# 15  loyalty cards      2024-09-03  Order Created                 false
# 2   loyalty cards      2024-09-03  Order Created                  true
# 4   loyalty cards      2024-09-04  Order Created                 false
# 12  loyalty cards      2024-09-04  Order Created                  true
# 6   loyalty cards      2024-09-05  Order Created                 false
# 14  loyalty cards      2024-09-05  Order Created                  true
# ...

# %% [markdown]
# ## store_membership_content_shown

# %%
#store_membership_content_shown
q.prepare_query('events/store_membership_content_shown.sql',params=params)
store_membership_content_shown = q.query_run_starburst(output_file='store_membership_content_shown',load_from_output_file=None,print_query=False)

store_membership_content_shown.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'origin'
    ,'is_loyalty_card_added'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\utils\query_engines.py:235: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#      project_name p_creation_date                      event_name  \
# 30  loyalty cards      2024-09-01  Store Membership Content Shown
# 41  loyalty cards      2024-09-01  Store Membership Content Shown
# 27  loyalty cards      2024-09-01  Store Membership Content Shown
# 42  loyalty cards      2024-09-01  Store Membership Content Shown
# 8   loyalty cards      2024-09-01  Store Membership Content Shown
# 40  loyalty cards      2024-09-01  Store Membership Content Shown
# 5   loyalty cards      2024-09-01  Store Membership Content Shown
# 10  loyalty cards      2024-09-02  Store Membership Content Shown
# ...

# %% [markdown]
# ## store_membership_interacted

# %%
#store_membership_interacted
q.prepare_query('events/store_membership_interacted.sql',params=params)
store_membership_interacted = q.query_run_starburst(output_file='store_membership_interacted',load_from_output_file=None,print_query=False)

store_membership_interacted.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'store_membership_interaction_type'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\utils\query_engines.py:235: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#      project_name p_creation_date                   event_name  \
# 1   loyalty cards      2024-09-01  Store Membership Interacted
# 11  loyalty cards      2024-09-01  Store Membership Interacted
# 23  loyalty cards      2024-09-01  Store Membership Interacted
# 6   loyalty cards      2024-09-02  Store Membership Interacted
# 18  loyalty cards      2024-09-02  Store Membership Interacted
# 4   loyalty cards      2024-09-02  Store Membership Interacted
# 5   loyalty cards      2024-09-03  Store Membership Interacted
# 7   loyalty cards      2024-09-03  Store Membership Interacted
# 16  loyalty cards      2024-09-03  Store Membership Interacted
# ...

# %% [markdown]
# ## tooltip_impression

# %%
#tooltip_impression
q.prepare_query('events/tooltip_impression.sql',params=params)
tooltip_impression  = q.query_run_starburst(output_file='tooltip_impression',load_from_output_file=None,print_query=False)

tooltip_impression.sort_values(by=[
    'project_name'
    ,'p_creation_date'
    ,'event_name'
    ,'tooltip_type'
])
# Out:
# c:\Users/Jordi Cremades/Documents/Repos/central-node\utils\query_engines.py:235: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
#     project_name p_creation_date          event_name  tooltip_type  \
# 6  loyalty cards      2024-09-01  Tooltip Impression  LoyaltyCards
# 1  loyalty cards      2024-09-02  Tooltip Impression  LoyaltyCards
# 4  loyalty cards      2024-09-03  Tooltip Impression  LoyaltyCards
# 7  loyalty cards      2024-09-04  Tooltip Impression  LoyaltyCards
# 0  loyalty cards      2024-09-05  Tooltip Impression  LoyaltyCards
# 2  loyalty cards      2024-09-06  Tooltip Impression  LoyaltyCards
# 5  loyalty cards      2024-09-07  Tooltip Impression  LoyaltyCards
# 3  loyalty cards      2024-09-08  Tooltip Impression  LoyaltyCards
#
#    count_event
# 6        18838
# ...
