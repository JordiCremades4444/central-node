# %% [markdown]
# # Issue CVR NSW vs Old sw

# %% [markdown]
# ## Executive summary

# %% [markdown]
# Has an obsidian notebook

# %% [markdown]
# ## Config

# %%
import matplotlib.pyplot as  plt
# import numpy as np
import pandas as pd
import seaborn as sns
import sys

sys.path.append('c:\\Users\\Jordi Cremades\\Documents\\Repos\\central-node')

# from utils import dataset_meta_stats
# from utils import dataset_stats
from utils import query_engines

# dms = dataset_meta_stats.DatasetMetaStats() 
# ds = dataset_stats.DatasetStats()

# %% [markdown]
# ## [X] Task 1: Are we missing info in any of the sources?

# %%
START_PREVIOUS_TO_CURRENT_DATE = 120
END_PREVIOUS_TO_CURRENT_DATE = 1
    
params = [
    {'name':'start_previous_to_current_date', 'value': str(START_PREVIOUS_TO_CURRENT_DATE)},
    {'name':'end_previous_to_current_date', 'value': str(END_PREVIOUS_TO_CURRENT_DATE)}
]

q = query_engines.QueryEngines(
    query='category_events.sql',
    params=params,
    printq=None
)

df = q.query_run_starbust()
df
# Out:
# c:\Users\Jordi Cremades\Documents\Repos\central-node\utils\query_engines.py:162: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/b739d11b95064ae5db26415ff28d1d18f4d2e13f71716d8174d61aa67315a9f8
#     p_creation_date  count_events
# 0        2024-05-04        211786
# 1        2024-04-07        192623
# 2        2024-03-08        205303
# 3        2024-01-23        171078
# 4        2024-03-22        166870
# ..              ...           ...
# 115      2024-03-01        177709
# 116      2024-02-12        190009
# 117      2024-04-30        183158
# 118      2024-02-05        179803
# 119      2024-02-09        213112
#
# [120 rows x 2 columns]

# %%
# plot
df['p_creation_date'] = pd.to_datetime(df['p_creation_date'])
df = df.sort_values('p_creation_date')

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(df['p_creation_date'], df['count_events'], marker='o', linestyle='-')
plt.title('Count of Events over Time')
plt.xlabel('Date')
plt.ylabel('Count of Events')
plt.xticks(rotation=45)
plt.grid(True)
plt.ylim(bottom=0)
plt.tight_layout()
plt.show()

# %%
START_PREVIOUS_TO_CURRENT_DATE = 120
END_PREVIOUS_TO_CURRENT_DATE = 1
    
params = [
    {'name':'start_previous_to_current_date', 'value': str(START_PREVIOUS_TO_CURRENT_DATE)},
    {'name':'end_previous_to_current_date', 'value': str(END_PREVIOUS_TO_CURRENT_DATE)}
]

q = query_engines.QueryEngines(
    query='sw_screen_views.sql',
    params=params,
    printq=None
)

df = q.query_run_starbust()
df
# Out:
# c:\Users\Jordi Cremades\Documents\Repos\central-node\utils\query_engines.py:162: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/beeed0db1bf63bbde474e75268b585a4e9ba35415ff45b3820487370e2ce9a05
#     p_creation_date  count_events
# 0        2024-01-30            70
# 1        2024-03-12            36
# 2        2024-04-08            15
# 3        2024-05-03            19
# 4        2024-01-17           198
# ..              ...           ...
# 235      2024-01-24        109781
# 236      2024-04-06        166010
# 237      2024-03-31        208384
# 238      2024-02-13         99849
# 239      2024-03-23        103154
#
# [240 rows x 2 columns]

# %%
tmp_gropuby = df.groupby(by='p_creation_date')['count_events'].sum().reset_index()
tmp_gropuby

# plot
tmp_gropuby['p_creation_date'] = pd.to_datetime(df['p_creation_date'])
tmp_gropuby = tmp_gropuby.sort_values('p_creation_date')

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(tmp_gropuby['p_creation_date'], tmp_gropuby['count_events'], marker='o', linestyle='-')
plt.title('Count of Events over Time')
plt.xlabel('Date')
plt.ylabel('Count of Events')
plt.xticks(rotation=45)
plt.grid(True)
plt.ylim(bottom=0)
plt.tight_layout()
plt.show()

# %%
START_PREVIOUS_TO_CURRENT_DATE = 180
END_PREVIOUS_TO_CURRENT_DATE = 1
    
params = [
    {'name':'start_previous_to_current_date', 'value': str(START_PREVIOUS_TO_CURRENT_DATE)},
    {'name':'end_previous_to_current_date', 'value': str(END_PREVIOUS_TO_CURRENT_DATE)}
]

q = query_engines.QueryEngines(
    query='store_screen_views.sql',
    params=params,
    printq=None
)

df = q.query_run_starbust()
df
# Out:
# c:\Users\Jordi Cremades\Documents\Repos\central-node\utils\query_engines.py:162: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/0aa64b77a5d3dc31e6fd1c6b9f0da913e7d24db7a14e6988a24fcc4d999d03bd
#     p_creation_date  count_events
# 0        2024-01-04        631860
# 1        2023-12-24        596342
# 2        2024-02-07        608651
# 3        2024-04-20        733345
# 4        2024-03-09        857030
# ..              ...           ...
# 175      2024-05-03        668444
# 176      2023-12-07        628364
# 177      2024-01-07        737148
# 178      2024-03-12        681639
# 179      2024-04-15        636971
#
# [180 rows x 2 columns]

# %%
# plot
df['p_creation_date'] = pd.to_datetime(df['p_creation_date'])
df = df.sort_values('p_creation_date')

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(df['p_creation_date'], df['count_events'], marker='o', linestyle='-')
plt.title('Count of Events over Time')
plt.xlabel('Date')
plt.ylabel('Count of Events')
plt.xticks(rotation=45)
plt.grid(True)
plt.ylim(bottom=0)
plt.tight_layout()
plt.show()

# %%
START_PREVIOUS_TO_CURRENT_DATE = 180
END_PREVIOUS_TO_CURRENT_DATE = 1
    
params = [
    {'name':'start_previous_to_current_date', 'value': str(START_PREVIOUS_TO_CURRENT_DATE)},
    {'name':'end_previous_to_current_date', 'value': str(END_PREVIOUS_TO_CURRENT_DATE)}
]

q = query_engines.QueryEngines(
    query='orders_created.sql',
    params=params,
    printq=None
)

df = q.query_run_starbust()
df
# Out:
# c:\Users\Jordi Cremades\Documents\Repos\central-node\utils\query_engines.py:162: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/afaae248c43c7afe3c9fabb59e1d0c3ae43a129f33dcf04585a771712b00231e
#     p_creation_date  count_events
# 0        2024-04-10        671427
# 1        2024-01-25        671462
# 2        2024-04-18        706055
# 3        2023-12-24        422848
# 4        2024-02-01        706877
# ..              ...           ...
# 175      2024-03-26        633129
# 176      2024-02-17        836175
# 177      2024-04-09        629717
# 178      2024-04-24        690430
# 179      2024-03-14        644784
#
# [180 rows x 2 columns]

# %%
# plot
df['p_creation_date'] = pd.to_datetime(df['p_creation_date'])
df = df.sort_values('p_creation_date')

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(df['p_creation_date'], df['count_events'], marker='o', linestyle='-')
plt.title('Count of Events over Time')
plt.xlabel('Date')
plt.ylabel('Count of Events')
plt.xticks(rotation=45)
plt.grid(True)
plt.ylim(bottom=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## [X] Task 2: New query

# %%
START_DATE = "'2023-12-01'"
END_DATE = "'2024-05-01'"

LIST_CATEGORY_ID = [4, 540, 622, 679, 682, 762, 875, 1015, 1082, 1195, 1197, 1214, 1314, 1316, 1551, 1718]
list_category_id = ",".join(str(val) for val in LIST_CATEGORY_ID)

params = [
    # category_id
    {'name':'list_category_id', 'value':list_category_id},
    # dates
    {'name':'start_date', 'value': str(START_DATE)},
    {'name':'end_date', 'value': str(END_DATE)}
]

q = query_engines.QueryEngines(
    query='new_query.sql',
    params=params,
    printq=None
)

df = q.query_run_starbust()
df
# Out:
# c:\Users\Jordi Cremades\Documents\Repos\central-node\utils\query_engines.py:162: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/f2bd9e8d289ef564a2a2febdbf4309ae93b113025d868dd513c8ecc955edf6cf
#            variant p_creation_date  ce_events  swe_events  oe_events
# 0    Control Group      2024-03-05      16516       16216       6156
# 1             None      2024-01-21       7563        7172       2267
# 2    Control Group      2023-12-25      17475       16166       3453
# 3             None      2024-03-06       3369        3136       1158
# 4        Variant 1      2023-12-07      82660       76756      18501
# ..             ...             ...        ...         ...        ...
# 454      Variant 1      2024-04-04     159046      104456      32216
# 455           None      2024-04-28       2901        2739        948
# 456      Variant 1      2024-01-09     198240       97086      32527
# 457           None      2023-12-22      11786       10699       3634
# 458           None      2024-02-24       4884        4556       1672
#
# [459 rows x 5 columns]

# %%
# tune it
df['variant_v2'] = df['variant'].fillna('not-found')
df
# Out:
#            variant p_creation_date  ce_events  swe_events  oe_events  \
# 46   Control Group      2023-12-01       6650        6080       1522
# 84            None      2023-12-01     161915      153593      55439
# 358      Variant 1      2023-12-01      68434       62581      14930
# 415  Control Group      2023-12-02       9259        8395       2250
# 425      Variant 1      2023-12-02      95392       87239      22320
# ..             ...             ...        ...         ...        ...
# 288           None      2024-04-30       2734        2545        987
# 441      Variant 1      2024-04-30     186601      130907      38958
# 44            None      2024-05-01       3764        3525        919
# 138      Variant 1      2024-05-01     236509      180706      41700
# 406  Control Group      2024-05-01      24193       23658       6822
#
#         variant_v2
# 46   Control Group
# 84       not-found
# 358      Variant 1
# 415  Control Group
# 425      Variant 1
# ..             ...
# 288      not-found
# 441      Variant 1
# 44       not-found
# 138      Variant 1
# 406  Control Group
#
# [459 rows x 6 columns]

# %%
df['p_creation_date'] = pd.to_datetime(df['p_creation_date'])

# Sort DataFrame by 'p_creation_date'
df = df.sort_values('p_creation_date')

# Plotting using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='p_creation_date', y='ce_events', hue='variant_v2', marker='o', linestyle='-')
plt.title('Number of Category opened events')
plt.xlabel('Date')
plt.ylabel('Number of events')
plt.xticks(rotation=45)
plt.grid(True)
plt.ylim(bottom=0)
plt.tight_layout()
plt.show()

# %%
df['cvr_swe_or'] = df['oe_events']/df['swe_events']
df['cvr_ce_or'] = df['oe_events']/df['ce_events']

# %%
df['p_creation_date'] = pd.to_datetime(df['p_creation_date'])

# Sort DataFrame by 'p_creation_date'
df = df.sort_values('p_creation_date')

# Plotting using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='p_creation_date', y='cvr_swe_or', hue='variant_v2', marker='o', linestyle='-')
plt.title('CVR% Category opened to Order created in Groceries stores)
plt.xlabel('Date')
plt.ylabel('Number of events')
plt.xticks(rotation=45)
plt.grid(True)
plt.ylim(bottom=0)
plt.tight_layout()
plt.show()

# %%
df['p_creation_date'] = pd.to_datetime(df['p_creation_date'])

# Sort DataFrame by 'p_creation_date'
df = df.sort_values('p_creation_date')

# Plotting using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='p_creation_date', y='cvr_ce_or', hue='variant_v2', marker='o', linestyle='-')
plt.title('Number of Category opened events')
plt.xlabel('Date')
plt.ylabel('Number of events')
plt.xticks(rotation=45)
plt.grid(True)
plt.ylim(bottom=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## [X] Task 3: New query simplifying the SWE part

# %%
START_DATE = "'2023-12-01'"
END_DATE = "'2024-05-01'"

LIST_CATEGORY_ID = [4, 540, 622, 679, 682, 762, 875, 1015, 1082, 1195, 1197, 1214, 1314, 1316, 1551, 1718]
list_category_id = ",".join(str(val) for val in LIST_CATEGORY_ID)

params = [
    # category_id
    {'name':'list_category_id', 'value':list_category_id},
    # dates
    {'name':'start_date', 'value': str(START_DATE)},
    {'name':'end_date', 'value': str(END_DATE)}
]

q = query_engines.QueryEngines(
    query='new_query_without_swe.sql',
    params=params,
    printq=None
)

df = q.query_run_starbust()
df
# Out:
# c:\Users\Jordi Cremades\Documents\Repos\central-node\utils\query_engines.py:162: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/6ecb95660dfdd693f138ed3baa32fccb6c59269fca06c76e4a576a04ba16a996
#            variant p_creation_date  ce_events  swe_events  oe_events
# 0             None      2024-02-01       4900        4597       1688
# 1        Variant 1      2024-03-13     154120       55324      17175
# 2    Control Group      2023-12-27      19074       17840       5978
# 3    Control Group      2024-03-14      16085       15654       5899
# 4    Control Group      2024-03-10      22190       21532       6859
# ..             ...             ...        ...         ...        ...
# 454      Variant 1      2024-04-10     178561      122612      36291
# 455  Control Group      2024-03-16      20903       20182       7824
# 456  Control Group      2024-04-03      17130       16430       6286
# 457           None      2024-01-22       6244        5805       2104
# 458      Variant 1      2024-04-15     177236      116187      37196
#
# [459 rows x 5 columns]

# %%
# tune it
df['variant_v2'] = df['variant'].fillna('not-found')
df
# Out:
#            variant p_creation_date  ce_events  swe_events  oe_events  \
# 0             None      2024-02-01       4900        4597       1688
# 1        Variant 1      2024-03-13     154120       55324      17175
# 2    Control Group      2023-12-27      19074       17840       5978
# 3    Control Group      2024-03-14      16085       15654       5899
# 4    Control Group      2024-03-10      22190       21532       6859
# ..             ...             ...        ...         ...        ...
# 454      Variant 1      2024-04-10     178561      122612      36291
# 455  Control Group      2024-03-16      20903       20182       7824
# 456  Control Group      2024-04-03      17130       16430       6286
# 457           None      2024-01-22       6244        5805       2104
# 458      Variant 1      2024-04-15     177236      116187      37196
#
#         variant_v2
# 0        not-found
# 1        Variant 1
# 2    Control Group
# 3    Control Group
# 4    Control Group
# ..             ...
# 454      Variant 1
# 455  Control Group
# 456  Control Group
# 457      not-found
# 458      Variant 1
#
# [459 rows x 6 columns]

# %%
df['cvr_swe_or'] = df['oe_events']/df['swe_events']
df['cvr_ce_or'] = df['oe_events']/df['ce_events']

# %%
df['p_creation_date'] = pd.to_datetime(df['p_creation_date'])

# Sort DataFrame by 'p_creation_date'
df = df.sort_values('p_creation_date')

# Plotting using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='p_creation_date', y='cvr_ce_or', hue='variant_v2', marker='o', linestyle='-')
plt.title('Number of Category opened events')
plt.xlabel('Date')
plt.ylabel('Number of events')
plt.xticks(rotation=45)
plt.grid(True)
plt.ylim(bottom=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## [X] Task 4: New query completely erasing the SW part of the funnel

# %%
START_DATE = "'2023-12-01'"
END_DATE = "'2024-05-01'"

LIST_CATEGORY_ID = [4, 540, 622, 679, 682, 762, 875, 1015, 1082, 1195, 1197, 1214, 1314, 1316, 1551, 1718]
list_category_id = ",".join(str(val) for val in LIST_CATEGORY_ID)

params = [
    # category_id
    {'name':'list_category_id', 'value':list_category_id},
    # dates
    {'name':'start_date', 'value': str(START_DATE)},
    {'name':'end_date', 'value': str(END_DATE)}
]

q = query_engines.QueryEngines(
    query='new_query_without_swe_v2.sql',
    params=params,
    printq=None,
    output_file='nsw_vs_old.csv'
)

df = q.query_run_starbust()
df
# Out:
# c:\Users\Jordi Cremades\Documents\Repos\central-node\utils\query_engines.py:162: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/b5e78fc522d24ff98d15a22606c82c7a136f324680aae0f4d48438b401cc9757
#            variant p_creation_date  ce_events  oe_events
# 0             None      2024-01-31       4457       1684
# 1             None      2024-01-04       8022       2634
# 2        Variant 1      2024-03-13     147238      55911
# 3    Control Group      2023-12-27      17574       5759
# 4             None      2024-03-06       3068       1105
# ..             ...             ...        ...        ...
# 454  Control Group      2024-03-23      18751       7042
# 455           None      2023-12-06     117907      42866
# 456      Variant 1      2024-01-07     217291      63144
# 457      Variant 1      2024-01-30     139802      53005
# 458      Variant 1      2024-03-07     151063      55526
#
# [459 rows x 4 columns]

# %%
# tune it
df['variant_v2'] = df['variant'].fillna('not-found')
df['cvr_ce_or'] = df['oe_events']/df['ce_events']
df
# Out:
#            variant p_creation_date  ce_events  oe_events     variant_v2  \
# 0             None      2024-01-31       4457       1684      not-found
# 1             None      2024-01-04       8022       2634      not-found
# 2        Variant 1      2024-03-13     147238      55911      Variant 1
# 3    Control Group      2023-12-27      17574       5759  Control Group
# 4             None      2024-03-06       3068       1105      not-found
# ..             ...             ...        ...        ...            ...
# 454  Control Group      2024-03-23      18751       7042  Control Group
# 455           None      2023-12-06     117907      42866      not-found
# 456      Variant 1      2024-01-07     217291      63144      Variant 1
# 457      Variant 1      2024-01-30     139802      53005      Variant 1
# 458      Variant 1      2024-03-07     151063      55526      Variant 1
#
#      cvr_ce_or
# 0     0.377833
# 1     0.328347
# 2     0.379732
# 3     0.327700
# 4     0.360169
# ..         ...
# 454   0.375553
# 455   0.363558
# 456   0.290596
# 457   0.379143
# 458   0.367568
#
# [459 rows x 6 columns]

# %%
df['p_creation_date'] = pd.to_datetime(df['p_creation_date'])

# Sort DataFrame by 'p_creation_date'
df = df.sort_values('p_creation_date')

# Plotting using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='p_creation_date', y='cvr_ce_or', hue='variant', linestyle='-')
plt.title('CVR% Category opened to Order created in Groceries stores')
plt.xlabel('Date')
plt.ylabel('Number of events')
plt.xticks(rotation=45)
plt.grid(True)
plt.ylim(bottom=0)
plt.tight_layout()
plt.show()

# %%
rolling_avg
# Out:
#         variant_v2 p_creation_date    ce_events   oe_events  cvr_ce_or
# 0    Control Group      2023-12-01          NaN         NaN        NaN
# 1    Control Group      2023-12-02          NaN         NaN        NaN
# 2    Control Group      2023-12-03          NaN         NaN        NaN
# 3    Control Group      2023-12-04          NaN         NaN        NaN
# 4    Control Group      2023-12-05          NaN         NaN        NaN
# ..             ...             ...          ...         ...        ...
# 454      not-found      2024-04-27  2639.857143  894.857143   0.339831
# 455      not-found      2024-04-28  2599.142857  887.714286   0.342084
# 456      not-found      2024-04-29  2622.714286  879.285714   0.335793
# 457      not-found      2024-04-30  2622.142857  888.000000   0.339414
# 458      not-found      2024-05-01  2782.571429  906.142857   0.328806
#
# [459 rows x 5 columns]

# %%
# Do a rolling average 
WINDOW = 21

# df.set_index('p_creation_date', inplace=True)

grouped = df.groupby('variant_v2')
rolling_avg = grouped[['ce_events', 'oe_events', 'cvr_ce_or']].rolling(window=WINDOW).mean()

rolling_avg.reset_index(inplace=True)

# Plotting using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(data=rolling_avg, x='p_creation_date', y='cvr_ce_or', hue='variant_v2', linestyle='-')
plt.title(f'Rolling CVR% {WINDOW} days - Category opened to Order created in Groceries stores')
plt.xlabel('Date')
plt.ylabel('CVR%')
plt.xticks(rotation=45)
plt.grid(True)
plt.ylim(bottom=0.28)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## [X] Task 5: InstorePrices

# %%
START_DATE = "'2023-12-01'"
END_DATE = "'2024-05-01'"

LIST_CATEGORY_ID = [4, 540, 622, 679, 682, 762, 875, 1015, 1082, 1195, 1197, 1214, 1314, 1316, 1551, 1718]
list_category_id = ",".join(str(val) for val in LIST_CATEGORY_ID)

params = [
    # category_id
    {'name':'list_category_id', 'value':list_category_id},
    # dates
    {'name':'start_date', 'value': str(START_DATE)},
    {'name':'end_date', 'value': str(END_DATE)}
]

q = query_engines.QueryEngines(
    query='new_query_without_swe_v3.sql',
    params=params,
    printq=None
)

df = q.query_run_starbust()
df
# Out:
# c:\Users\Jordi Cremades\Documents\Repos\central-node\utils\query_engines.py:162: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(self.tp__read_query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/a82cf9cfba0db7b9b184099ae7a0689b35f2e2118ccc31a50a29399fd7b2412a
#       nswg_variant    ipg_variant p_creation_date  ce_events  oe_events
# 0        Variant 1           None      2024-04-28      27969       4575
# 1             None           None      2023-12-16      12348       4285
# 2    Control Group           None      2024-03-17      19563       6392
# 3        Variant 1  Control Group      2024-03-11     102477      42953
# 4    Control Group  Control Group      2024-04-09          5          2
# ..             ...            ...             ...        ...        ...
# 874           None           None      2024-03-19       3177       1086
# 875  Control Group           None      2023-12-27      17573       5749
# 876      Variant 1  Control Group      2024-05-01     134629      42608
# 877  Control Group           None      2024-03-18      17356       6628
# 878      Variant 1  InStorePrices      2024-01-24       2221        920
#
# [879 rows x 5 columns]

# %%
# tune it
df['ipg_variant_v2'] = df['ipg_variant'].fillna('not-found')
df['nswg_variant_v2'] = df['nswg_variant'].fillna('not-found')
df['cvr_ce_or'] = df['oe_events']/df['ce_events']

# %%
cond = df['nswg_variant_v2'] == 'Variant 1'

df['p_creation_date'] = pd.to_datetime(df['p_creation_date'])
# Sort DataFrame by 'p_creation_date'
df = df.sort_values('p_creation_date')

# Plotting using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(data=df[cond], x='p_creation_date', y='cvr_ce_or', hue='ipg_variant_v2', linestyle='-', ci=None)
plt.title('Instore Prices: CVR% Category opened to Order created in Groceries stores')
plt.xlabel('Date')
plt.ylabel('Number of events')
plt.xticks(rotation=45)
plt.grid(True)
plt.ylim(bottom=0)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Jordi Cremades\AppData\Local\Temp\ipykernel_17136\4108178380.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.lineplot(data=df[cond], x='p_creation_date', y='cvr_ce_or', hue='ipg_variant_v2', linestyle='-', ci=None)
# C:\Users\Jordi Cremades\AppData\Local\Temp\ipykernel_17136\4108178380.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df[cond], x='p_creation_date', y='cvr_ce_or', hue='ipg_variant_v2', linestyle='-', ci=None)

# %%
cond = df['nswg_variant_v2'] == 'Variant 1'

df['p_creation_date'] = pd.to_datetime(df['p_creation_date'])
# Sort DataFrame by 'p_creation_date'
df = df.sort_values('p_creation_date')

# Plotting using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(data=df[cond], x='p_creation_date', y='oe_events', hue='ipg_variant_v2', linestyle='-', ci=None)
plt.title('Number of Order Created Events')
plt.xlabel('Date')
plt.ylabel('Number of events')
plt.xticks(rotation=45)
plt.grid(True)
plt.ylim(bottom=0)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Jordi Cremades\AppData\Local\Temp\ipykernel_17136\2675654672.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.lineplot(data=df[cond], x='p_creation_date', y='oe_events', hue='ipg_variant_v2', linestyle='-', ci=None)
# C:\Users\Jordi Cremades\AppData\Local\Temp\ipykernel_17136\2675654672.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df[cond], x='p_creation_date', y='oe_events', hue='ipg_variant_v2', linestyle='-', ci=None)

# %%
cond = df['nswg_variant_v2'] == 'Variant 1'

df['p_creation_date'] = pd.to_datetime(df['p_creation_date'])
# Sort DataFrame by 'p_creation_date'
df = df.sort_values('p_creation_date')

# Plotting using Seaborn
plt.figure(figsize=(10, 6))
sns.lineplot(data=df[cond], x='p_creation_date', y='ce_events', hue='ipg_variant_v2', linestyle='-', ci=None)
plt.title('Number of Category Opened Events')
plt.xlabel('Date')
plt.ylabel('Number of events')
plt.xticks(rotation=45)
plt.grid(True)
plt.ylim(bottom=0)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Jordi Cremades\AppData\Local\Temp\ipykernel_17136\3750276714.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   sns.lineplot(data=df[cond], x='p_creation_date', y='ce_events', hue='ipg_variant_v2', linestyle='-', ci=None)
# C:\Users\Jordi Cremades\AppData\Local\Temp\ipykernel_17136\3750276714.py:9: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=df[cond], x='p_creation_date', y='ce_events', hue='ipg_variant_v2', linestyle='-', ci=None)
